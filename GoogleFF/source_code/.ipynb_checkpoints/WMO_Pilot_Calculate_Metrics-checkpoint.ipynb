# %%
import json
import os
import shutil
import xarray as xr

# %%
import calculate_metrics
import return_period_metrics
import benchmarks
import uruguay as provider

# %%
import pandas as pd
# Out:
# Timedelta('30 days 00:00:00')

# %% [markdown]
# # Hydrographs

# %% [markdown]
# ## Gauge-to-Run Mapping

# %%
# Load mapping from gauge to model run directory.
with open(provider.GAUGE_TO_MODEL_PATH_MAPPING_FILE, 'r') as f:
  gauge_to_model_path = json.load(f)

# Experiment names.
experiments = list(gauge_to_model_path.keys())
experiments
# Out:
# ['gauged',
#  'ungauged',
#  'random_cross_validation',
#  'hydrologically_separated_cross_validation']

# %% [markdown]
# ## Load Model Runs

# %%
# experiment = 'hydrologically_separated_cross_validation'
# gauge = 'DNAUY_10.1'
# gauge_to_model_path[experiment][gauge] = gauge_to_model_path[experiment][gauge].replace('model_runs_4', 'model_runs_4_1')

# for gauge in gauge_to_model_path[experiment]:
#   if 'fold_44' in gauge_to_model_path[experiment][gauge]:
#     gauge_to_model_path[experiment][gauge] = gauge_to_model_path[experiment][gauge].replace('model_runs_4', 'model_runs_4_1')

# provider.MODEL_RUN_DIRECTORY

# %%
hydrographs = {
    experiment: calculate_metrics.load_model_runs_for_experiment(
        experiment=experiment,
        gauges=provider.TRAIN_GAUGES,
        model_run_base_path=provider.MODEL_RUN_DIRECTORY,
    ) for experiment in experiments
}
hydrographs['gauged']
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:      (gauge_id: 19, time: 2922, lead_time: 8)
# Coordinates:
#   * time         (time) datetime64[ns] 23kB 2016-01-01 2016-01-02 ... 2023-12-31
#   * lead_time    (lead_time) int32 32B 0 1 2 3 4 5 6 7
#   * gauge_id     (gauge_id) object 152B 'DNAUY_52' ... 'DNAUY_176.1'
# Data variables:
#     observation  (gauge_id, time, lead_time) float64 4MB 8.427 7.57 ... nan nan
#     prediction   (gauge_id, time, lead_time) float64 4MB 9.4 7.962 ... 0.06444

# %% [markdown]
# ## Create Benchmarks

# %% [markdown]
# ### Persistence Benchmark

# %%
benchmark = 'persistence'
hydrographs[benchmark] = benchmarks.persistence_benchmark(
    baseline_hydrographs=hydrographs['gauged'],
)
hydrographs[benchmark]
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:      (gauge_id: 19, time: 2922, lead_time: 8)
# Coordinates:
#   * gauge_id     (gauge_id) object 152B 'DNAUY_52' ... 'DNAUY_176.1'
#   * time         (time) datetime64[ns] 23kB 2016-01-01 2016-01-02 ... 2023-12-31
#   * lead_time    (lead_time) int32 32B 0 1 2 3 4 5 6 7
# Data variables:
#     prediction   (gauge_id, time, lead_time) float64 4MB 8.427 8.427 ... nan nan
#     observation  (gauge_id, time, lead_time) float64 4MB 8.427 7.57 ... nan nan

# %% [markdown]
# ### Climatology Benchmark

# %%
benchmark = 'monthly_climatology'
hydrographs[benchmark] = benchmarks.monthly_climatology_benchmark(
    observed_hydrograph=hydrographs['gauged'],
)
hydrographs[benchmark]
# Out:
# <xarray.Dataset> Size: 7MB
# Dimensions:      (gauge_id: 19, time: 2922, lead_time: 8)
# Coordinates:
#   * gauge_id     (gauge_id) <U11 836B 'DNAUY_52' 'DNAUY_1743' ... 'DNAUY_176.1'
#   * time         (time) datetime64[ns] 23kB 2016-01-01 2016-01-02 ... 2023-12-31
#   * lead_time    (lead_time) int32 32B 0 1 2 3 4 5 6 7
# Data variables:
#     prediction   (gauge_id, time, lead_time) float64 4MB 3.091 3.091 ... nan nan
#     observation  (gauge_id, time, lead_time) float64 4MB 8.427 7.57 ... nan nan

# %% [markdown]
# ### GloFAS Benchmark

# %% [markdown]
# ### Provider Forecasts Benchmark

# %% [markdown]
# # Metrics

# %% [markdown]
# ## Calculate Hydrograph Metrics

# %%
hydrograph_metrics_ds = calculate_metrics.compute_metrics_for_all_experiments(hydrographs)
hydrograph_metrics_ds
# Out:
# Calculating metrics for experiment: gauged ...
#   0%|                                                                                                                                                                                                                                                              | 0/19 [00:00<?, ?it/s]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#   5%|████████████▉                                                                                                                                                                                                                                         | 1/19 [00:01<00:23,  1.31s/it]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#  11%|█████████████████████████▉                                                                                                                                                                                                                            | 2/19 [00:02<00:20,  1.19s/it]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#  16%|██████████████████████████████████████▊                                                                                                                                                                                                               | 3/19 [00:03<00:20,  1.31s/it]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#  21%|███████████████████████████████████████████████████▊                                                                                                                                                                                                  | 4/19 [00:05<00:19,  1.31s/it]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#  26%|████████████████████████████████████████████████████████████████▋                                                                                                                                                                                     | 5/19 [00:06<00:18,  1.35s/it]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#  32%|█████████████████████████████████████████████████████████████████████████████▋                                                                                                                                                                        | 6/19 [00:07<00:16,  1.30s/it]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#  37%|██████████████████████████████████████████████████████████████████████████████████████████▋                                                                                                                                                           | 7/19 [00:08<00:15,  1.25s/it]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#  42%|███████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                              | 8/19 [00:10<00:13,  1.26s/it]/home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# /home/gsnearing/source_code/metrics.py:80: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/gsnearing/source_code/metrics.py:135: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
#  47%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                                                 | 9/19 [00:10<00:11,  1.18s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_754171/16377119.py in ?()
# ----> 1 hydrograph_metrics_ds = calculate_metrics.compute_metrics_for_all_experiments(hydrographs)
#       2 hydrograph_metrics_ds
#
# ~/source_code/calculate_metrics.py in ?(hydrographs)
#     193   }
#     194
#     195   for e, experiment in enumerate(hydrographs.keys()):
#     196     print(f'Calculating metrics for experiment: {experiment} ...')
# --> 197     experiment_metrics = _compute_metrics_for_experiment(
#     198         hydrographs[experiment])
#     199     if experiment_metrics is None:
#     200       continue
#
# ~/source_code/calculate_metrics.py in ?(hydrographs)
#     159       obs = hydrographs.sel(
#     160           {'gauge_id': gauge, 'lead_time': lead_time}).observation
#     161       sim = hydrographs.sel(
#     162           {'gauge_id': gauge, 'lead_time': lead_time}).prediction
# --> 163       gauge_metrics = metrics.calculate_all_metrics(
#     164           obs, sim, datetime_coord='time')
#     165       metrics_dfs[gauge].append(pd.Series(gauge_metrics, name=lead_time))
#     166     metrics_dfs[gauge] = pd.concat(metrics_dfs[gauge], axis=1)
#
# ~/source_code/metrics.py in ?(obs, sim, resolution, datetime_coord, minimum_data_points)
#     894       ),
#     895       'FLV': fdc_flv(obs, sim),
#     896       'FHV': fdc_fhv(obs, sim),
#     897       'FMS': fdc_fms(obs, sim),
# --> 898       'Missed-Peaks': missed_peaks(
#     899           obs, sim, resolution=resolution, datetime_coord=datetime_coord
#     900       ),
#     901       'Peak-MAPE': mean_absolute_percentage_peak_error(obs, sim)
#
# ~/source_code/metrics.py in ?(obs, sim, window, resolution, percentile, datetime_coord)
#     652     # that span too much time).
#     653     if ((idx - window < 0) or(idx + window >= len(obs)) or
#     654         pd.date_range(
#     655             obs[idx - window][datetime_coord].values,
# --> 656             obs[idx + window][datetime_coord].values,
#     657             freq=resolution).size != 2 * window + 1):
#     658       continue
#     659
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/dataarray.py in ?(self, key)
#     872         if isinstance(key, str):
#     873             return self._getitem_coord(key)
#     874         else:
#     875             # xarray-style array indexing
# --> 876             return self.isel(indexers=self._item_key_to_dict(key))
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/dataarray.py in ?(self, indexers, drop, missing_dims, **indexers_kwargs)
#    1497
#    1498         indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    1499
#    1500         if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 1501             ds = self._to_temp_dataset()._isel_fancy(
#    1502                 indexers, drop=drop, missing_dims=missing_dims
#    1503             )
#    1504             return self._from_temp_dataset(ds)
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/dataset.py in ?(self, indexers, drop, missing_dims)
#    3025                 var_indexers = {
#    3026                     k: v for k, v in valid_indexers.items() if k in var.dims
#    3027                 }
#    3028                 if var_indexers:
# -> 3029                     new_var = var.isel(indexers=var_indexers)
#    3030                     # drop scalar coordinates
#    3031                     # https://github.com/pydata/xarray/issues/6554
#    3032                     if name in self.coords and drop and new_var.ndim == 0:
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/variable.py in ?(self, indexers, missing_dims, **indexers_kwargs)
#    1029
#    1030         indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1031
#    1032         key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1033         return self[key]
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/variable.py in ?(self, key)
#     800         data = indexing.apply_indexer(indexable, indexer)
#     801
#     802         if new_order:
#     803             data = np.moveaxis(data, range(len(new_order)), new_order)
# --> 804         return self._finalize_indexing_result(dims, data)
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/variable.py in ?(self, dims, data)
#    2678     def _finalize_indexing_result(self, dims, data):
#    2679         if getattr(data, "ndim", 0) != 1:
#    2680             # returns Variable rather than IndexVariable if multi-dimensional
# -> 2681             return Variable(dims, data, self._attrs, self._encoding)
#    2682         else:
#    2683             return self._replace(dims=dims, data=data)
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/variable.py in ?(self, dims, data, attrs, encoding, fastpath)
#     394             Well-behaved code to serialize a Variable should ignore
#     395             unrecognized encoding items.
#     396         """
#     397         super().__init__(
# --> 398             dims=dims, data=as_compatible_data(data, fastpath=fastpath), attrs=attrs
#     399         )
#     400
#     401         self._encoding = None
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/variable.py in ?(data, fastpath)
#     316     # validate whether the data is valid data types.
#     317     data = np.asarray(data)
#     318
#     319     if isinstance(data, np.ndarray) and data.dtype.kind in "OMm":
# --> 320         data = _possibly_convert_objects(data)
#     321     return _maybe_wrap_data(data)
#
# ~/miniconda3/lib/python3.12/site-packages/xarray/core/variable.py in ?(values)
#     228     through pandas.Series objects ensures that datetimes and timedeltas are
#     229     within the valid date range for ns precision, as pandas will raise an error
#     230     if they are not.
#     231     """
# --> 232     as_series = pd.Series(values.ravel(), copy=False)
#     233     if as_series.dtype.kind in "mM":
#     234         as_series = _as_nanosecond_precision(as_series)
#     235     result = np.asarray(as_series).reshape(values.shape)
#
# ~/miniconda3/lib/python3.12/site-packages/pandas/core/series.py in ?(self, data, index, dtype, name, copy, fastpath)
#     588                 data = SingleBlockManager.from_array(data, index, refs=refs)
#     589             elif manager == "array":
#     590                 data = SingleArrayManager.from_array(data, index)
#     591
# --> 592         NDFrame.__init__(self, data)
#     593         self.name = name
#     594         self._set_axis(0, index)
#     595
#
# ~/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, data)
#     278     def __init__(self, data: Manager) -> None:
#     279         object.__setattr__(self, "_is_copy", None)
#     280         object.__setattr__(self, "_mgr", data)
# --> 281         object.__setattr__(self, "_item_cache", {})
#     282         object.__setattr__(self, "_attrs", {})
#     283         object.__setattr__(self, "_flags", Flags(self, allows_duplicate_labels=True))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Calculate Return Period Metrics

# %%
return_period_dss = []
for experiment, hydrograph in hydrographs.items():
  print(f'Calculating return period metrics for experiment: {experiment} ...')
  if hydrograph is not None:
    return_period_dss.append(return_period_metrics.compute_metrics(hydrograph, experiment))
return_period_ds = xr.concat(return_period_dss, dim='experiment')
return_period_ds

# %% [markdown]
# ## Save as NetCDF

# %%
metrics_ds = xr.merge([hydrograph_metrics_ds, return_period_ds])
metrics_ds

# %%
# metrics_file = f'{provider.EXPERIMENT_RESULTS_PATH}/metrics.nc'
# with gfile.Open(metrics_file, 'wb') as f:
#   metrics_ds.to_netcdf(f)
