# %% [markdown]
# # HydroSOS - Persistence and Hydrological Analogues method

# %% [markdown]
# In this notebook, we explore the Persistance and Hydrological Analogue method

# %% [markdown]
# ## Import the python libraries

# %%
# %reset -f

# %%
# Importing the libraries
import pandas as pd
import seaborn as sns
import numpy as np
import calendar
import datetime
import matplotlib.pyplot as plt
import math
from scipy import stats
plt.style.use('classic')
# %matplotlib inline

from IPython.display import HTML

sns.set()

# %%
# install a conda package in the current Jupyter kernel
#import sys
#!conda install --yes --prefix {sys.prefix} missingno

# %%
# import missingno

# %% [markdown]
# ### We create function for percentile definition

# %%
# Quantile Function Definitions
def q1(x):
    return x.quantile(0.28)

def q2(x):
    return x.median()

def q3(x):
    return x.quantile(0.72)

def q5(x):
    return x.quantile(0.05)

def q95(x):
    return x.quantile(0.95)

def q87(x):
    return x.quantile(0.87)

def q13(x):
    return x.quantile(0.13)

# %% [markdown]
# We create a function called add_month that add the number of months based on an input date. This will be used in the Jack-Knife Validation

# %%
def add_months(sourcedate, months):
    month = sourcedate.month - 1 + months
    year = sourcedate.year + month // 12
    month = month % 12 + 1
    day = min(sourcedate.day, calendar.monthrange(year,month)[1])
    return datetime.date(year, month, day)

# %% [markdown]
# the monthly anomalies of the most recently past months are compared with all possible historical sequences of anomalies covering the same months of the year. That is, if the recent past covers, say, the months February to July, then potential analogues are sought only in the February to July sequences of the historical record

# %% [markdown]
# Define a Root Mean Square Error Function. This function will be used to select the analogues years

# %%
def rmse(predictions,targets):
    return np.around(((predictions - targets) ** 2).mean() ** 0.5,4)

# %% [markdown]
# ## Import Data

# %% [markdown]
# In this example we import the daily discharge data from Fray Marcos station, from 01 Jan 1980 to 31 Jan 2023. We import and then visualize head and tail of dataframe, plot timeseries and also make boxplot for daily discharge grouped by month.

# %%
MONTHLY_ANOMALY = pd.read_csv('../notebook_verificacion/santalucia_caudales_prueba_MA.csv',parse_dates=['Month'],index_col="Month",na_values="")

# %%
MONTHLY_ANOMALY
# Out:
#            1980      1981      1982      1983      1984      1985      1986  \
# Month
# 1     -1.536267  0.458249 -0.907146 -0.078435  1.595684 -0.569929  0.060480
# 2      0.241717  0.425784  0.164443  0.037709  2.259184 -1.246188 -0.407393
# 3      1.049742 -0.458319 -0.471385 -1.056707  1.123855  0.667133 -1.002581
# 4      1.300559 -0.274466 -0.475394 -0.507639 -0.272078  0.587747 -0.743722
# 5      1.075049  1.482334  0.656692 -0.915862  0.460168  0.516957  0.075766
# 6      0.632953 -0.280376  0.994073  0.146152  0.978806  0.530937  0.359025
# 7      0.682468  0.350652  0.620029 -0.290099  1.561809  0.633409  0.125589
# 8      0.109535  0.413811  0.234558  0.751669       NaN  0.220850  1.386902
# 9     -0.353978  0.614313  0.479720  1.523802 -0.010080  0.475918  1.003092
# 10     0.536702 -0.677438       NaN  1.351341  0.231029  0.671122  0.774743
# 11    -0.331749 -1.306468       NaN  0.847118  0.809480  0.336701  1.217815
# 12     1.297617  0.572945       NaN -0.275393 -1.162990 -0.915141  0.701937
#
#        1987      1988      1989  ...  2014  2015  2016  2017  2018  2019  \
# Month                            ...
# 1       NaN  1.695788 -0.609378  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2       NaN  0.119670 -1.349524  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3       NaN  1.681609 -1.100457  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4       NaN  0.717188 -1.221652  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 5       NaN -0.967284 -1.966323  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 6       NaN -1.301700 -2.108455  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 7       NaN -0.615400 -1.530132  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 8       NaN -0.485248 -0.442800  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 9       NaN -1.031575 -1.350103  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 10      NaN -1.142164 -1.737324  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 11      NaN -0.726399 -1.502100  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 12      NaN -1.251198 -0.235918  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#        2020  2021  2022  2023
# Month
# 1       NaN   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN
# 3       NaN   NaN   NaN   NaN
# 4       NaN   NaN   NaN   NaN
# 5       NaN   NaN   NaN   NaN
# 6       NaN   NaN   NaN   NaN
# 7       NaN   NaN   NaN   NaN
# 8       NaN   NaN   NaN   NaN
# 9       NaN   NaN   NaN   NaN
# 10      NaN   NaN   NaN   NaN
# 11      NaN   NaN   NaN   NaN
# 12      NaN   NaN   NaN   NaN
#
# [12 rows x 44 columns]

# %%
DISCHARGE_MONTHLY = pd.read_csv('../notebook_verificacion/santalucia_caudales_prueba_DA.csv',parse_dates=['Fecha'],index_col="Fecha",na_values="")

# %%
DISCHARGE_MONTHLY
# Out:
#              Discharge  Year  Month  water_year  Q_to_log  Anomaly_Qlog
# Fecha
# 1980-01-31    1.198613  1980      1        1980  0.181165     -1.536267
# 1980-02-29   28.386414  1980      2        1980  3.345911      0.241717
# 1980-03-31   86.782323  1980      3        1980  4.463403      1.049742
# 1980-04-30  172.187367  1980      4        1981  5.148583      1.300559
# 1980-05-31  275.560258  1980      5        1981  5.618806      1.075049
# ...                ...   ...    ...         ...       ...           ...
# 2022-12-31         NaN  2022     12        2023       NaN           NaN
# 2023-01-31         NaN  2023      1        2023       NaN           NaN
# 2023-02-28         NaN  2023      2        2023       NaN           NaN
# 2023-03-31         NaN  2023      3        2023       NaN           NaN
# 2023-04-30         NaN  2023      4        2024       NaN           NaN
#
# [520 rows x 6 columns]

# %%
YEAR_HINDCAST_SELECTED = np.unique(DISCHARGE_MONTHLY['Year'])
# rename columns change str for int
MONTHLY_ANOMALY.columns = YEAR_HINDCAST_SELECTED

# %%
YEAR_HINDCAST_SELECTED
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001,
#        2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023],
#       dtype=int64)

# %%
range_analysis = range(YEAR_HINDCAST_SELECTED[0],YEAR_HINDCAST_SELECTED[11])

# %%
LOG_DISCHARGE_MONTHLY_PIVOT = pd.pivot_table(DISCHARGE_MONTHLY, index=['Month'],columns=['Year'], values=['Q_to_log'],dropna=False)
LOG_DISCHARGE_MONTHLY_PIVOT.columns = YEAR_HINDCAST_SELECTED

# %%
LOG_DISCHARGE_MONTHLY_PIVOT
# Out:
#            1980      1981      1982      1983      1984      1985      1986  \
# Month
# 1      0.181165  2.266864  0.839047  1.705645  3.456299  1.191681  1.850911
# 2      3.345911  3.596570  3.240681  3.068096  6.093265  1.319706  2.461964
# 3      4.463403  2.653676  2.637997  1.935590  4.552342  4.004259  2.000542
# 4      5.148583  3.169494  2.917019  2.876502  3.172495  4.252904  2.579853
# 5      5.618806  6.181355  5.040966  2.868932  4.769523  4.847961  4.238582
# 6      5.431652  4.226532  5.908143  4.789328  5.887999  5.297043  5.070209
# 7      5.315642  4.974052  5.251364  4.314426  6.220885  5.265138  4.742359
# 8      5.119868  5.464556  5.261496  5.847285       NaN  5.245967  6.566886
# 9      4.117590  5.092622  4.957092  6.008443  4.463882  4.953263  5.484107
# 10     4.931459  3.168846       NaN  6.114101  4.487702  5.126601  5.277033
# 11     3.681058  2.351966       NaN  5.288520  5.237198  4.592534  5.793989
# 12     4.098310  3.458490       NaN  2.709484  1.925816  2.144644  3.572378
#
#        1987      1988      1989  ...  2014  2015  2016  2017  2018  2019  \
# Month                            ...
# 1       NaN  3.560980  1.150429  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2       NaN  3.179709  1.178985  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3       NaN  5.221666  1.883088  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4       NaN  4.415552  1.979313  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 5       NaN  2.797907  1.418020  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 6       NaN  2.878916  1.814417  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 7       NaN  3.979544  3.037866  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 8       NaN  4.446090  4.494176  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 9       NaN  3.435276  3.114530  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 10      NaN  2.494186  1.630170  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 11      NaN  3.142927  2.085208  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 12      NaN  1.847937  2.744337  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#        2020  2021  2022  2023
# Month
# 1       NaN   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN
# 3       NaN   NaN   NaN   NaN
# 4       NaN   NaN   NaN   NaN
# 5       NaN   NaN   NaN   NaN
# 6       NaN   NaN   NaN   NaN
# 7       NaN   NaN   NaN   NaN
# 8       NaN   NaN   NaN   NaN
# 9       NaN   NaN   NaN   NaN
# 10      NaN   NaN   NaN   NaN
# 11      NaN   NaN   NaN   NaN
# 12      NaN   NaN   NaN   NaN
#
# [12 rows x 44 columns]

# %%
ANOMALY_ANALOGUES = MONTHLY_ANOMALY[range_analysis]
QLOG_ANALOGUES = LOG_DISCHARGE_MONTHLY_PIVOT[range_analysis]
HTML(ANOMALY_ANALOGUES.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>1980</th>
#       <th>1981</th>
#       <th>1982</th>
#       <th>1983</th>
#       <th>1984</th>
#       <th>1985</th>
#       <th>1986</th>
#       <th>1987</th>
#       <th>1988</th>
#       <th>1989</th>
#       <th>1990</th>
#     </tr>
#     <tr>
#       <th>Month</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>-1.536267</td>
#       <td>0.458249</td>
#       <td>-0.907146</td>
#       <td>-0.078435</td>
#       <td>1.595684</td>
#       <td>-0.569929</td>
#       <td>0.060480</td>
#       <td>NaN</td>
#       <td>1.695788</td>
#       <td>-0.609378</td>
#       <td>-0.540918</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.241717</td>
#       <td>0.425784</td>
#       <td>0.164443</td>
#       <td>0.037709</td>
#       <td>2.259184</td>
#       <td>-1.246188</td>
#       <td>-0.407393</td>
#       <td>NaN</td>
#       <td>0.119670</td>
#       <td>-1.349524</td>
#       <td>0.599554</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.049742</td>
#       <td>-0.458319</td>
#       <td>-0.471385</td>
#       <td>-1.056707</td>
#       <td>1.123855</td>
#       <td>0.667133</td>
#       <td>-1.002581</td>
#       <td>NaN</td>
#       <td>1.681609</td>
#       <td>-1.100457</td>
#       <td>0.285230</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.300559</td>
#       <td>-0.274466</td>
#       <td>-0.475394</td>
#       <td>-0.507639</td>
#       <td>-0.272078</td>
#       <td>0.587747</td>
#       <td>-0.743722</td>
#       <td>NaN</td>
#       <td>0.717188</td>
#       <td>-1.221652</td>
#       <td>1.923675</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.075049</td>
#       <td>1.482334</td>
#       <td>0.656692</td>
#       <td>-0.915862</td>
#       <td>0.460168</td>
#       <td>0.516957</td>
#       <td>0.075766</td>
#       <td>NaN</td>
#       <td>-0.967284</td>
#       <td>-1.966323</td>
#       <td>-0.170332</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.632953</td>
#       <td>-0.280376</td>
#       <td>0.994073</td>
#       <td>0.146152</td>
#       <td>0.978806</td>
#       <td>0.530937</td>
#       <td>0.359025</td>
#       <td>NaN</td>
#       <td>-1.301700</td>
#       <td>-2.108455</td>
#       <td>0.048584</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.682468</td>
#       <td>0.350652</td>
#       <td>0.620029</td>
#       <td>-0.290099</td>
#       <td>1.561809</td>
#       <td>0.633409</td>
#       <td>0.125589</td>
#       <td>NaN</td>
#       <td>-0.615400</td>
#       <td>-1.530132</td>
#       <td>-1.538323</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.109535</td>
#       <td>0.413811</td>
#       <td>0.234558</td>
#       <td>0.751669</td>
#       <td>NaN</td>
#       <td>0.220850</td>
#       <td>1.386902</td>
#       <td>NaN</td>
#       <td>-0.485248</td>
#       <td>-0.442800</td>
#       <td>-2.189276</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>-0.353978</td>
#       <td>0.614313</td>
#       <td>0.479720</td>
#       <td>1.523802</td>
#       <td>-0.010080</td>
#       <td>0.475918</td>
#       <td>1.003092</td>
#       <td>NaN</td>
#       <td>-1.031575</td>
#       <td>-1.350103</td>
#       <td>-1.351109</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.536702</td>
#       <td>-0.677438</td>
#       <td>NaN</td>
#       <td>1.351341</td>
#       <td>0.231029</td>
#       <td>0.671122</td>
#       <td>0.774743</td>
#       <td>NaN</td>
#       <td>-1.142164</td>
#       <td>-1.737324</td>
#       <td>-0.008010</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>-0.331749</td>
#       <td>-1.306468</td>
#       <td>NaN</td>
#       <td>0.847118</td>
#       <td>0.809480</td>
#       <td>0.336701</td>
#       <td>1.217815</td>
#       <td>NaN</td>
#       <td>-0.726399</td>
#       <td>-1.502100</td>
#       <td>0.655603</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>1.297617</td>
#       <td>0.572945</td>
#       <td>NaN</td>
#       <td>-0.275393</td>
#       <td>-1.162990</td>
#       <td>-0.915141</td>
#       <td>0.701937</td>
#       <td>NaN</td>
#       <td>-1.251198</td>
#       <td>-0.235918</td>
#       <td>1.268143</td>
#     </tr>
#   </tbody>
# </table>

# %%
ANOMALY_ANALOGUE_TS = pd.melt(ANOMALY_ANALOGUES.reset_index(), id_vars='Month',var_name=['Year'],ignore_index = True)
ANOMALY_ANALOGUE_TS.columns = ['Month','Year','Anomaly_Qlog']
HTML(ANOMALY_ANALOGUE_TS.head(6).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Month</th>
#       <th>Year</th>
#       <th>Anomaly_Qlog</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1980</td>
#       <td>-1.536267</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1980</td>
#       <td>0.241717</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1980</td>
#       <td>1.049742</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>1980</td>
#       <td>1.300559</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>1980</td>
#       <td>1.075049</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>1980</td>
#       <td>0.632953</td>
#     </tr>
#   </tbody>
# </table>

# %%
QLOG_ANALOGUE_TS = pd.melt(QLOG_ANALOGUES.reset_index(), id_vars='Month',var_name=['Year'],ignore_index = True)
QLOG_ANALOGUE_TS.columns = ['Month','Year','Qlog']
HTML(QLOG_ANALOGUE_TS.head(6).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Month</th>
#       <th>Year</th>
#       <th>Qlog</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>1980</td>
#       <td>0.181165</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>1980</td>
#       <td>3.345911</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>1980</td>
#       <td>4.463403</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>1980</td>
#       <td>5.148583</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>1980</td>
#       <td>5.618806</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>6</td>
#       <td>1980</td>
#       <td>5.431652</td>
#     </tr>
#   </tbody>
# </table>

# %%
ANOMALY_ANALOGUE_TS['DATE'] = pd.to_datetime(ANOMALY_ANALOGUE_TS[['Year', 'Month']].assign(DAY=1))
HTML(ANOMALY_ANALOGUE_TS.head(6).to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Month</th>
#       <th>Year</th>
#       <th>Anomaly_Qlog</th>
#       <th>DATE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1980</td>
#       <td>-1.536267</td>
#       <td>1980-01-01</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1980</td>
#       <td>0.241717</td>
#       <td>1980-02-01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1980</td>
#       <td>1.049742</td>
#       <td>1980-03-01</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1980</td>
#       <td>1.300559</td>
#       <td>1980-04-01</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1980</td>
#       <td>1.075049</td>
#       <td>1980-05-01</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1980</td>
#       <td>0.632953</td>
#       <td>1980-06-01</td>
#     </tr>
#   </tbody>
# </table>

# %%
######## PARTE CENTRAL

# %% [markdown]
# ## HINDCAST PARA FORECAST_LENGHT EN MESES

# %%
## define Dana last months of observation
DANA = 6
## define forecast lenght in months
FORECAST_LENGTH = 1
##

# %%
##
# Toma como argumentos
# range_analysis - > YEAR_ANALYSIS
# QLOG_ANALOGUES
# QLOG_ANALOGUE_TS
# ANOMALY_ANALOGUES
# ANOMALY_ANALOGUE_TS
# MONTH_ANALYSIS
# DANA
# FORECAST_LENGTH
##


YEAR_ANALYSIS = range_analysis # definir al menos para tener DANA meses para atras con datos..

MONTH_ANALYSIS = range(1,13,1)
df = pd.DataFrame()
ANOMALY_HISTORICAL = pd.DataFrame()
RMSE = []
ANO_TARG = []
ANO_PRED = []
MON_TARG = []
MON_PRED = []
TARG = []
PRED = []
OBS_ANOM = []

MEAN_ANOM_HIND = []
STD_ANOM_HIND = []
Q1_ANOM_HIND = []
Q3_ANOM_HIND = []

MEAN_QLOG_HIND = []
STD_QLOG_HIND = []

##
print('Dana selected: ',DANA, 'months')
print('Forecast length selected: ', FORECAST_LENGTH , 'months')
##


for y in YEAR_ANALYSIS:    
            
    
    for m in MONTH_ANALYSIS:
        
        if m < 12:
            # From the Qlog values, drop the monthly values for the year of analysis and mantain the remaining years. 
            # This is the Qlog hindcast series
            # print('Dropping year:',y,"-","End-Month:",m)
            print('Dropping year:',y," - get series for analysis.")
            QLOG_HINDCAST_TARG_ANALOGUE = QLOG_ANALOGUES.drop([y],axis=1)
            QLOG_HINDCAST_TARG_ANALOGUE_TS = QLOG_ANALOGUE_TS[QLOG_ANALOGUE_TS['Year'] != y]

            # From the monthly anomaly values, drop the monthly values for the year of analysis and mantain the remaining years. 
            # This is the anomaly hindcast series
            ANOMALY_HINDCAST_TARG_ANALOGUE = ANOMALY_ANALOGUES.drop([y],axis=1)
            ANOMALY_HINDCAST_TARG_ANALOGUE_TS = ANOMALY_ANALOGUE_TS[ANOMALY_ANALOGUE_TS['Year'] != y]
        
        elif m==12 and y<YEAR_ANALYSIS[-1]:
            # From the Qlog values, drop the monthly values for the year of analysis and mantain the remaining years. 
            # This is the Qlog hindcast series
            # print('Dropping year:',y,"-","End-Month:",m)
            print('Dropping year:',y," - get series for analysis.")
            QLOG_HINDCAST_TARG_ANALOGUE = QLOG_ANALOGUES.drop([y+1],axis=1)
            QLOG_HINDCAST_TARG_ANALOGUE_TS = QLOG_ANALOGUE_TS[QLOG_ANALOGUE_TS['Year'] != y+1]

            # From the monthly anomaly values, drop the monthly values for the year of analysis and mantain the remaining years. 
            # This is the anomaly hindcast series
            ANOMALY_HINDCAST_TARG_ANALOGUE = ANOMALY_ANALOGUES.drop([y+1],axis=1)
            ANOMALY_HINDCAST_TARG_ANALOGUE_TS = ANOMALY_ANALOGUE_TS[ANOMALY_ANALOGUE_TS['Year'] != y+1]

            
        print('Year:',y,"-","End-Month of observation:",m)
        # define end month and year based on the for-loop
        END_DATE_HIST = datetime.date.today().replace(year=y, month=m, day=1)

        # define initial date according to Dana past months of observation
        FIRST_DATE_HIST = add_months(END_DATE_HIST,-DANA)
        
        # query in the original anomaly time serie the first date and end_date
        ANOMALY_TARGET = ANOMALY_ANALOGUE_TS.query('DATE > @FIRST_DATE_HIST & DATE <= @END_DATE_HIST')
        print(ANOMALY_TARGET)
        
        # Check if there are enough months in the past
        if ANOMALY_TARGET.index.size < DANA:
            print('There are not enough months in the past')
            print('')
        
        else:
            print('There are enough months in the past')
            print(f"Target period: {add_months(FIRST_DATE_HIST,1).strftime('%m-%Y')} to {(END_DATE_HIST.strftime('%m-%Y'))}")
            
            # Define a list with the targets months
            MONTHS_TARG = pd.date_range(add_months(FIRST_DATE_HIST,1),add_months(END_DATE_HIST,1),freq='M').month.to_list()
            
            # Get the anomaly hindcast target series
            ANOMALY_HINDCAST_TARG = ANOMALY_ANALOGUE_TS.drop(ANOMALY_TARGET.index)
            ANOMALY_HINDCAST_TARG = ANOMALY_HINDCAST_TARG.query('Month == @MONTHS_TARG').reset_index()
            
            # Get the anomaly target series
            df['target'] = ANOMALY_TARGET["Anomaly_Qlog"].values.round(5)

            # Adjust anomaly hindcast target series index
            if MONTHS_TARG[0]>=MONTHS_TARG[-1]:
                print('Target period includes two years')
                print('')
                if ANOMALY_HINDCAST_TARG['Month'][0] != MONTHS_TARG[0]:
                    ANOMALY_HINDCAST_TARG.drop([*range(0,ANOMALY_HINDCAST_TARG[ANOMALY_HINDCAST_TARG['Month']==MONTHS_TARG[0]].index.min())],inplace=True)
                    ANOMALY_HINDCAST_TARG.reset_index(drop=True)
                    # print(len(ANOMALY_HINDCAST_TARG.index)/DANA)

            else:
                print('Target period includes only one year')
                print('')
                pass

            # Iterate over de anomaly hindcast target where are the potential analogues
            for i in range(0, int(len(ANOMALY_HINDCAST_TARG.index)/DANA)):

                
                # create a dataframe (df) for the "preditec" (analogue) and "target" (current year)
                df['predicted'] = ANOMALY_HINDCAST_TARG.iloc[i*DANA:(i+1)*DANA,1:-1]["Anomaly_Qlog"].values.round(5)
                
                # save month and year value of target series
                ANO_TARG.append(f"{str(ANOMALY_HINDCAST_TARG.iloc[i*DANA:(i+1)*DANA,1:-1]['Year'].tolist()[0])}-{str(ANOMALY_HINDCAST_TARG.iloc[i*DANA:(i+1)*DANA,1:-1]['Year'].tolist()[-1])}")
                MON_TARG.append(MONTHS_TARG)
                
                # save month and year value of predicted series
                ANO_PRED.append(add_months(END_DATE_HIST, FORECAST_LENGTH).year)
                MON_PRED.append(add_months(END_DATE_HIST, FORECAST_LENGTH).month)            

                # define the date to get the anomaly value of the actual month of the potential analogue
                DATE_DANA=datetime.date.today().replace(year=ANOMALY_HINDCAST_TARG.iloc[i*DANA:(i+1)*DANA]['Year'].values[-1], month=ANOMALY_HINDCAST_TARG.iloc[i*DANA:(i+1)*DANA]['Month'].values[-1], day=1)
                
                # get the anomaly value of the following month of the potential analogue
                ANOMALY_OBS = ANOMALY_ANALOGUE_TS.query('DATE == @add_months(@DATE_DANA,@FORECAST_LENGTH)')['Anomaly_Qlog'].values
                # print(ANOMALY_OBS)
                
                # get the mean and standard deviation of monthly anomaly series use for hindcast necessary for rescale de forecast
                MEAN_ANOM_HIND.append(ANOMALY_HINDCAST_TARG_ANALOGUE.loc[add_months(DATE_DANA,FORECAST_LENGTH).month].mean())
                STD_ANOM_HIND.append(ANOMALY_HINDCAST_TARG_ANALOGUE.loc[add_months(DATE_DANA,FORECAST_LENGTH).month].std())           
                
                # get statistic of monthly anomaly serie use for hindcast necesary contingency tables
                Q1_ANOM_HIND.append(q1(ANOMALY_HINDCAST_TARG_ANALOGUE.loc[add_months(DATE_DANA,FORECAST_LENGTH).month]))
                Q3_ANOM_HIND.append(q3(ANOMALY_HINDCAST_TARG_ANALOGUE.loc[add_months(DATE_DANA,FORECAST_LENGTH).month]))  
                
                # get the mean and standard deviation of monthly qlog series use for hindcast 
                MEAN_QLOG_HIND.append(QLOG_HINDCAST_TARG_ANALOGUE.loc[add_months(DATE_DANA,FORECAST_LENGTH).month].mean())
                STD_QLOG_HIND.append(QLOG_HINDCAST_TARG_ANALOGUE.loc[add_months(DATE_DANA,FORECAST_LENGTH).month].std())

                
                try:
                    if math.isnan(ANOMALY_OBS):
                        #print('Next month to end-month is nan')
                        RMSE_val = np.nan
                        RMSE.append(RMSE_val)
                        TARG.append(df['target'].values.tolist())
                        PRED.append(df['predicted'].values.tolist())
                        OBS_ANOM.append(np.nan)
                    else:
                        #print('Next month to end-month is not empty')
                        if df['predicted'].isnull().values.any() == False:
                            # calculate the RMSE
                            RMSE_val = rmse(df['predicted'],df['target'])
                            # append in the empty lists
                            RMSE.append(RMSE_val)
                            TARG.append(df['target'].values.tolist())
                            PRED.append(df['predicted'].values.tolist())
                            OBS_ANOM.append(ANOMALY_OBS.round(5)[0])
                        else:
                            RMSE_val = np.nan
                            RMSE.append(RMSE_val)
                            TARG.append(df['target'].values.tolist())
                            PRED.append(df['predicted'].values.tolist())
                            OBS_ANOM.append(np.nan)
                except:
                    if ANOMALY_OBS.size == 0:
                        #print('Next month to end-month is empty')
                        RMSE_val = np.nan
                        RMSE.append(RMSE_val)
                        TARG.append(df['target'].values.tolist())
                        PRED.append(df['predicted'].values.tolist())
                        OBS_ANOM.append(np.nan)
# Out:
# Dana selected:  6 months
# Forecast length selected:  1 months
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 1
#    Month  Year  Anomaly_Qlog       DATE
# 0      1  1980     -1.536267 1980-01-01
# There are not enough months in the past
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 2
#    Month  Year  Anomaly_Qlog       DATE
# 0      1  1980     -1.536267 1980-01-01
# 1      2  1980      0.241717 1980-02-01
# There are not enough months in the past
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 3
#    Month  Year  Anomaly_Qlog       DATE
# 0      1  1980     -1.536267 1980-01-01
# 1      2  1980      0.241717 1980-02-01
# 2      3  1980      1.049742 1980-03-01
# There are not enough months in the past
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 4
#    Month  Year  Anomaly_Qlog       DATE
# 0      1  1980     -1.536267 1980-01-01
# 1      2  1980      0.241717 1980-02-01
# 2      3  1980      1.049742 1980-03-01
# 3      4  1980      1.300559 1980-04-01
# There are not enough months in the past
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 5
#    Month  Year  Anomaly_Qlog       DATE
# 0      1  1980     -1.536267 1980-01-01
# 1      2  1980      0.241717 1980-02-01
# 2      3  1980      1.049742 1980-03-01
# 3      4  1980      1.300559 1980-04-01
# 4      5  1980      1.075049 1980-05-01
# There are not enough months in the past
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 6
#    Month  Year  Anomaly_Qlog       DATE
# 0      1  1980     -1.536267 1980-01-01
# 1      2  1980      0.241717 1980-02-01
# 2      3  1980      1.049742 1980-03-01
# 3      4  1980      1.300559 1980-04-01
# 4      5  1980      1.075049 1980-05-01
# 5      6  1980      0.632953 1980-06-01
# There are enough months in the past
# Target period: 01-1980 to 06-1980
# Target period includes only one year
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 7
#    Month  Year  Anomaly_Qlog       DATE
# 1      2  1980      0.241717 1980-02-01
# 2      3  1980      1.049742 1980-03-01
# 3      4  1980      1.300559 1980-04-01
# 4      5  1980      1.075049 1980-05-01
# 5      6  1980      0.632953 1980-06-01
# 6      7  1980      0.682468 1980-07-01
# There are enough months in the past
# Target period: 02-1980 to 07-1980
# Target period includes only one year
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 8
#    Month  Year  Anomaly_Qlog       DATE
# 2      3  1980      1.049742 1980-03-01
# 3      4  1980      1.300559 1980-04-01
# 4      5  1980      1.075049 1980-05-01
# 5      6  1980      0.632953 1980-06-01
# 6      7  1980      0.682468 1980-07-01
# 7      8  1980      0.109535 1980-08-01
# There are enough months in the past
# Target period: 03-1980 to 08-1980
# Target period includes only one year
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 9
#    Month  Year  Anomaly_Qlog       DATE
# 3      4  1980      1.300559 1980-04-01
# 4      5  1980      1.075049 1980-05-01
# 5      6  1980      0.632953 1980-06-01
# 6      7  1980      0.682468 1980-07-01
# 7      8  1980      0.109535 1980-08-01
# 8      9  1980     -0.353978 1980-09-01
# There are enough months in the past
# Target period: 04-1980 to 09-1980
# Target period includes only one year
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 10
#    Month  Year  Anomaly_Qlog       DATE
# 4      5  1980      1.075049 1980-05-01
# 5      6  1980      0.632953 1980-06-01
# 6      7  1980      0.682468 1980-07-01
# 7      8  1980      0.109535 1980-08-01
# 8      9  1980     -0.353978 1980-09-01
# 9     10  1980      0.536702 1980-10-01
# There are enough months in the past
# Target period: 05-1980 to 10-1980
# Target period includes only one year
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 11
#     Month  Year  Anomaly_Qlog       DATE
# 5       6  1980      0.632953 1980-06-01
# 6       7  1980      0.682468 1980-07-01
# 7       8  1980      0.109535 1980-08-01
# 8       9  1980     -0.353978 1980-09-01
# 9      10  1980      0.536702 1980-10-01
# 10     11  1980     -0.331749 1980-11-01
# There are enough months in the past
# Target period: 06-1980 to 11-1980
# Target period includes only one year
#
# Dropping year: 1980  - get series for analysis.
# Year: 1980 - End-Month of observation: 12
#     Month  Year  Anomaly_Qlog       DATE
# 6       7  1980      0.682468 1980-07-01
# 7       8  1980      0.109535 1980-08-01
# 8       9  1980     -0.353978 1980-09-01
# 9      10  1980      0.536702 1980-10-01
# 10     11  1980     -0.331749 1980-11-01
# 11     12  1980      1.297617 1980-12-01
# There are enough months in the past
# Target period: 07-1980 to 12-1980
# Target period includes only one year
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 1
#     Month  Year  Anomaly_Qlog       DATE
# 7       8  1980      0.109535 1980-08-01
# 8       9  1980     -0.353978 1980-09-01
# 9      10  1980      0.536702 1980-10-01
# 10     11  1980     -0.331749 1980-11-01
# 11     12  1980      1.297617 1980-12-01
# 12      1  1981      0.458249 1981-01-01
# There are enough months in the past
# Target period: 08-1980 to 01-1981
# Target period includes two years
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 2
#     Month  Year  Anomaly_Qlog       DATE
# 8       9  1980     -0.353978 1980-09-01
# 9      10  1980      0.536702 1980-10-01
# 10     11  1980     -0.331749 1980-11-01
# 11     12  1980      1.297617 1980-12-01
# 12      1  1981      0.458249 1981-01-01
# 13      2  1981      0.425784 1981-02-01
# There are enough months in the past
# Target period: 09-1980 to 02-1981
# Target period includes two years
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 3
#     Month  Year  Anomaly_Qlog       DATE
# 9      10  1980      0.536702 1980-10-01
# 10     11  1980     -0.331749 1980-11-01
# 11     12  1980      1.297617 1980-12-01
# 12      1  1981      0.458249 1981-01-01
# 13      2  1981      0.425784 1981-02-01
# 14      3  1981     -0.458319 1981-03-01
# There are enough months in the past
# Target period: 10-1980 to 03-1981
# Target period includes two years
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 4
#     Month  Year  Anomaly_Qlog       DATE
# 10     11  1980     -0.331749 1980-11-01
# 11     12  1980      1.297617 1980-12-01
# 12      1  1981      0.458249 1981-01-01
# 13      2  1981      0.425784 1981-02-01
# 14      3  1981     -0.458319 1981-03-01
# 15      4  1981     -0.274466 1981-04-01
# There are enough months in the past
# Target period: 11-1980 to 04-1981
# Target period includes two years
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 5
#     Month  Year  Anomaly_Qlog       DATE
# 11     12  1980      1.297617 1980-12-01
# 12      1  1981      0.458249 1981-01-01
# 13      2  1981      0.425784 1981-02-01
# 14      3  1981     -0.458319 1981-03-01
# 15      4  1981     -0.274466 1981-04-01
# 16      5  1981      1.482334 1981-05-01
# There are enough months in the past
# Target period: 12-1980 to 05-1981
# Target period includes two years
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 6
#     Month  Year  Anomaly_Qlog       DATE
# 12      1  1981      0.458249 1981-01-01
# 13      2  1981      0.425784 1981-02-01
# 14      3  1981     -0.458319 1981-03-01
# 15      4  1981     -0.274466 1981-04-01
# 16      5  1981      1.482334 1981-05-01
# 17      6  1981     -0.280376 1981-06-01
# There are enough months in the past
# Target period: 01-1981 to 06-1981
# Target period includes only one year
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 7
#     Month  Year  Anomaly_Qlog       DATE
# 13      2  1981      0.425784 1981-02-01
# 14      3  1981     -0.458319 1981-03-01
# 15      4  1981     -0.274466 1981-04-01
# 16      5  1981      1.482334 1981-05-01
# 17      6  1981     -0.280376 1981-06-01
# 18      7  1981      0.350652 1981-07-01
# There are enough months in the past
# Target period: 02-1981 to 07-1981
# Target period includes only one year
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 8
#     Month  Year  Anomaly_Qlog       DATE
# 14      3  1981     -0.458319 1981-03-01
# 15      4  1981     -0.274466 1981-04-01
# 16      5  1981      1.482334 1981-05-01
# 17      6  1981     -0.280376 1981-06-01
# 18      7  1981      0.350652 1981-07-01
# 19      8  1981      0.413811 1981-08-01
# There are enough months in the past
# Target period: 03-1981 to 08-1981
# Target period includes only one year
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 9
#     Month  Year  Anomaly_Qlog       DATE
# 15      4  1981     -0.274466 1981-04-01
# 16      5  1981      1.482334 1981-05-01
# 17      6  1981     -0.280376 1981-06-01
# 18      7  1981      0.350652 1981-07-01
# 19      8  1981      0.413811 1981-08-01
# 20      9  1981      0.614313 1981-09-01
# There are enough months in the past
# Target period: 04-1981 to 09-1981
# Target period includes only one year
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 10
#     Month  Year  Anomaly_Qlog       DATE
# 16      5  1981      1.482334 1981-05-01
# 17      6  1981     -0.280376 1981-06-01
# 18      7  1981      0.350652 1981-07-01
# 19      8  1981      0.413811 1981-08-01
# 20      9  1981      0.614313 1981-09-01
# 21     10  1981     -0.677438 1981-10-01
# There are enough months in the past
# Target period: 05-1981 to 10-1981
# Target period includes only one year
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 11
#     Month  Year  Anomaly_Qlog       DATE
# 17      6  1981     -0.280376 1981-06-01
# 18      7  1981      0.350652 1981-07-01
# 19      8  1981      0.413811 1981-08-01
# 20      9  1981      0.614313 1981-09-01
# 21     10  1981     -0.677438 1981-10-01
# 22     11  1981     -1.306468 1981-11-01
# There are enough months in the past
# Target period: 06-1981 to 11-1981
# Target period includes only one year
#
# Dropping year: 1981  - get series for analysis.
# Year: 1981 - End-Month of observation: 12
#     Month  Year  Anomaly_Qlog       DATE
# 18      7  1981      0.350652 1981-07-01
# 19      8  1981      0.413811 1981-08-01
# 20      9  1981      0.614313 1981-09-01
# 21     10  1981     -0.677438 1981-10-01
# 22     11  1981     -1.306468 1981-11-01
# 23     12  1981      0.572945 1981-12-01
# There are enough months in the past
# Target period: 07-1981 to 12-1981
# Target period includes only one year
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 1
#     Month  Year  Anomaly_Qlog       DATE
# 19      8  1981      0.413811 1981-08-01
# 20      9  1981      0.614313 1981-09-01
# 21     10  1981     -0.677438 1981-10-01
# 22     11  1981     -1.306468 1981-11-01
# 23     12  1981      0.572945 1981-12-01
# 24      1  1982     -0.907146 1982-01-01
# There are enough months in the past
# Target period: 08-1981 to 01-1982
# Target period includes two years
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 2
#     Month  Year  Anomaly_Qlog       DATE
# 20      9  1981      0.614313 1981-09-01
# 21     10  1981     -0.677438 1981-10-01
# 22     11  1981     -1.306468 1981-11-01
# 23     12  1981      0.572945 1981-12-01
# 24      1  1982     -0.907146 1982-01-01
# 25      2  1982      0.164443 1982-02-01
# There are enough months in the past
# Target period: 09-1981 to 02-1982
# Target period includes two years
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 3
#     Month  Year  Anomaly_Qlog       DATE
# 21     10  1981     -0.677438 1981-10-01
# 22     11  1981     -1.306468 1981-11-01
# 23     12  1981      0.572945 1981-12-01
# 24      1  1982     -0.907146 1982-01-01
# 25      2  1982      0.164443 1982-02-01
# 26      3  1982     -0.471385 1982-03-01
# There are enough months in the past
# Target period: 10-1981 to 03-1982
# Target period includes two years
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 4
#     Month  Year  Anomaly_Qlog       DATE
# 22     11  1981     -1.306468 1981-11-01
# 23     12  1981      0.572945 1981-12-01
# 24      1  1982     -0.907146 1982-01-01
# 25      2  1982      0.164443 1982-02-01
# 26      3  1982     -0.471385 1982-03-01
# 27      4  1982     -0.475394 1982-04-01
# There are enough months in the past
# Target period: 11-1981 to 04-1982
# Target period includes two years
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 5
#     Month  Year  Anomaly_Qlog       DATE
# 23     12  1981      0.572945 1981-12-01
# 24      1  1982     -0.907146 1982-01-01
# 25      2  1982      0.164443 1982-02-01
# 26      3  1982     -0.471385 1982-03-01
# 27      4  1982     -0.475394 1982-04-01
# 28      5  1982      0.656692 1982-05-01
# There are enough months in the past
# Target period: 12-1981 to 05-1982
# Target period includes two years
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 6
#     Month  Year  Anomaly_Qlog       DATE
# 24      1  1982     -0.907146 1982-01-01
# 25      2  1982      0.164443 1982-02-01
# 26      3  1982     -0.471385 1982-03-01
# 27      4  1982     -0.475394 1982-04-01
# 28      5  1982      0.656692 1982-05-01
# 29      6  1982      0.994073 1982-06-01
# There are enough months in the past
# Target period: 01-1982 to 06-1982
# Target period includes only one year
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 7
#     Month  Year  Anomaly_Qlog       DATE
# 25      2  1982      0.164443 1982-02-01
# 26      3  1982     -0.471385 1982-03-01
# 27      4  1982     -0.475394 1982-04-01
# 28      5  1982      0.656692 1982-05-01
# 29      6  1982      0.994073 1982-06-01
# 30      7  1982      0.620029 1982-07-01
# There are enough months in the past
# Target period: 02-1982 to 07-1982
# Target period includes only one year
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 8
#     Month  Year  Anomaly_Qlog       DATE
# 26      3  1982     -0.471385 1982-03-01
# 27      4  1982     -0.475394 1982-04-01
# 28      5  1982      0.656692 1982-05-01
# 29      6  1982      0.994073 1982-06-01
# 30      7  1982      0.620029 1982-07-01
# 31      8  1982      0.234558 1982-08-01
# There are enough months in the past
# Target period: 03-1982 to 08-1982
# Target period includes only one year
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 9
#     Month  Year  Anomaly_Qlog       DATE
# 27      4  1982     -0.475394 1982-04-01
# 28      5  1982      0.656692 1982-05-01
# 29      6  1982      0.994073 1982-06-01
# 30      7  1982      0.620029 1982-07-01
# 31      8  1982      0.234558 1982-08-01
# 32      9  1982      0.479720 1982-09-01
# There are enough months in the past
# Target period: 04-1982 to 09-1982
# Target period includes only one year
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 10
#     Month  Year  Anomaly_Qlog       DATE
# 28      5  1982      0.656692 1982-05-01
# 29      6  1982      0.994073 1982-06-01
# 30      7  1982      0.620029 1982-07-01
# 31      8  1982      0.234558 1982-08-01
# 32      9  1982      0.479720 1982-09-01
# 33     10  1982           NaN 1982-10-01
# There are enough months in the past
# Target period: 05-1982 to 10-1982
# Target period includes only one year
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 11
#     Month  Year  Anomaly_Qlog       DATE
# 29      6  1982      0.994073 1982-06-01
# 30      7  1982      0.620029 1982-07-01
# 31      8  1982      0.234558 1982-08-01
# 32      9  1982      0.479720 1982-09-01
# 33     10  1982           NaN 1982-10-01
# 34     11  1982           NaN 1982-11-01
# There are enough months in the past
# Target period: 06-1982 to 11-1982
# Target period includes only one year
#
# Dropping year: 1982  - get series for analysis.
# Year: 1982 - End-Month of observation: 12
#     Month  Year  Anomaly_Qlog       DATE
# 30      7  1982      0.620029 1982-07-01
# 31      8  1982      0.234558 1982-08-01
# 32      9  1982      0.479720 1982-09-01
# 33     10  1982           NaN 1982-10-01
# 34     11  1982           NaN 1982-11-01
# 35     12  1982           NaN 1982-12-01
# There are enough months in the past
# Target period: 07-1982 to 12-1982
# Target period includes only one year
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 1
#     Month  Year  Anomaly_Qlog       DATE
# 31      8  1982      0.234558 1982-08-01
# 32      9  1982      0.479720 1982-09-01
# 33     10  1982           NaN 1982-10-01
# 34     11  1982           NaN 1982-11-01
# 35     12  1982           NaN 1982-12-01
# 36      1  1983     -0.078435 1983-01-01
# There are enough months in the past
# Target period: 08-1982 to 01-1983
# Target period includes two years
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 2
#     Month  Year  Anomaly_Qlog       DATE
# 32      9  1982      0.479720 1982-09-01
# 33     10  1982           NaN 1982-10-01
# 34     11  1982           NaN 1982-11-01
# 35     12  1982           NaN 1982-12-01
# 36      1  1983     -0.078435 1983-01-01
# 37      2  1983      0.037709 1983-02-01
# There are enough months in the past
# Target period: 09-1982 to 02-1983
# Target period includes two years
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 3
#     Month  Year  Anomaly_Qlog       DATE
# 33     10  1982           NaN 1982-10-01
# 34     11  1982           NaN 1982-11-01
# 35     12  1982           NaN 1982-12-01
# 36      1  1983     -0.078435 1983-01-01
# 37      2  1983      0.037709 1983-02-01
# 38      3  1983     -1.056707 1983-03-01
# There are enough months in the past
# Target period: 10-1982 to 03-1983
# Target period includes two years
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 4
#     Month  Year  Anomaly_Qlog       DATE
# 34     11  1982           NaN 1982-11-01
# 35     12  1982           NaN 1982-12-01
# 36      1  1983     -0.078435 1983-01-01
# 37      2  1983      0.037709 1983-02-01
# 38      3  1983     -1.056707 1983-03-01
# 39      4  1983     -0.507639 1983-04-01
# There are enough months in the past
# Target period: 11-1982 to 04-1983
# Target period includes two years
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 5
#     Month  Year  Anomaly_Qlog       DATE
# 35     12  1982           NaN 1982-12-01
# 36      1  1983     -0.078435 1983-01-01
# 37      2  1983      0.037709 1983-02-01
# 38      3  1983     -1.056707 1983-03-01
# 39      4  1983     -0.507639 1983-04-01
# 40      5  1983     -0.915862 1983-05-01
# There are enough months in the past
# Target period: 12-1982 to 05-1983
# Target period includes two years
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 6
#     Month  Year  Anomaly_Qlog       DATE
# 36      1  1983     -0.078435 1983-01-01
# 37      2  1983      0.037709 1983-02-01
# 38      3  1983     -1.056707 1983-03-01
# 39      4  1983     -0.507639 1983-04-01
# 40      5  1983     -0.915862 1983-05-01
# 41      6  1983      0.146152 1983-06-01
# There are enough months in the past
# Target period: 01-1983 to 06-1983
# Target period includes only one year
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 7
#     Month  Year  Anomaly_Qlog       DATE
# 37      2  1983      0.037709 1983-02-01
# 38      3  1983     -1.056707 1983-03-01
# 39      4  1983     -0.507639 1983-04-01
# 40      5  1983     -0.915862 1983-05-01
# 41      6  1983      0.146152 1983-06-01
# 42      7  1983     -0.290099 1983-07-01
# There are enough months in the past
# Target period: 02-1983 to 07-1983
# Target period includes only one year
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 8
#     Month  Year  Anomaly_Qlog       DATE
# 38      3  1983     -1.056707 1983-03-01
# 39      4  1983     -0.507639 1983-04-01
# 40      5  1983     -0.915862 1983-05-01
# 41      6  1983      0.146152 1983-06-01
# 42      7  1983     -0.290099 1983-07-01
# 43      8  1983      0.751669 1983-08-01
# There are enough months in the past
# Target period: 03-1983 to 08-1983
# Target period includes only one year
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 9
#     Month  Year  Anomaly_Qlog       DATE
# 39      4  1983     -0.507639 1983-04-01
# 40      5  1983     -0.915862 1983-05-01
# 41      6  1983      0.146152 1983-06-01
# 42      7  1983     -0.290099 1983-07-01
# 43      8  1983      0.751669 1983-08-01
# 44      9  1983      1.523802 1983-09-01
# There are enough months in the past
# Target period: 04-1983 to 09-1983
# Target period includes only one year
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 10
#     Month  Year  Anomaly_Qlog       DATE
# 40      5  1983     -0.915862 1983-05-01
# 41      6  1983      0.146152 1983-06-01
# 42      7  1983     -0.290099 1983-07-01
# 43      8  1983      0.751669 1983-08-01
# 44      9  1983      1.523802 1983-09-01
# 45     10  1983      1.351341 1983-10-01
# There are enough months in the past
# Target period: 05-1983 to 10-1983
# Target period includes only one year
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 11
#     Month  Year  Anomaly_Qlog       DATE
# 41      6  1983      0.146152 1983-06-01
# 42      7  1983     -0.290099 1983-07-01
# 43      8  1983      0.751669 1983-08-01
# 44      9  1983      1.523802 1983-09-01
# 45     10  1983      1.351341 1983-10-01
# 46     11  1983      0.847118 1983-11-01
# There are enough months in the past
# Target period: 06-1983 to 11-1983
# Target period includes only one year
#
# Dropping year: 1983  - get series for analysis.
# Year: 1983 - End-Month of observation: 12
#     Month  Year  Anomaly_Qlog       DATE
# 42      7  1983     -0.290099 1983-07-01
# 43      8  1983      0.751669 1983-08-01
# 44      9  1983      1.523802 1983-09-01
# 45     10  1983      1.351341 1983-10-01
# 46     11  1983      0.847118 1983-11-01
# 47     12  1983     -0.275393 1983-12-01
# There are enough months in the past
# Target period: 07-1983 to 12-1983
# Target period includes only one year
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 1
#     Month  Year  Anomaly_Qlog       DATE
# 43      8  1983      0.751669 1983-08-01
# 44      9  1983      1.523802 1983-09-01
# 45     10  1983      1.351341 1983-10-01
# 46     11  1983      0.847118 1983-11-01
# 47     12  1983     -0.275393 1983-12-01
# 48      1  1984      1.595684 1984-01-01
# There are enough months in the past
# Target period: 08-1983 to 01-1984
# Target period includes two years
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 2
#     Month  Year  Anomaly_Qlog       DATE
# 44      9  1983      1.523802 1983-09-01
# 45     10  1983      1.351341 1983-10-01
# 46     11  1983      0.847118 1983-11-01
# 47     12  1983     -0.275393 1983-12-01
# 48      1  1984      1.595684 1984-01-01
# 49      2  1984      2.259184 1984-02-01
# There are enough months in the past
# Target period: 09-1983 to 02-1984
# Target period includes two years
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 3
#     Month  Year  Anomaly_Qlog       DATE
# 45     10  1983      1.351341 1983-10-01
# 46     11  1983      0.847118 1983-11-01
# 47     12  1983     -0.275393 1983-12-01
# 48      1  1984      1.595684 1984-01-01
# 49      2  1984      2.259184 1984-02-01
# 50      3  1984      1.123855 1984-03-01
# There are enough months in the past
# Target period: 10-1983 to 03-1984
# Target period includes two years
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 4
#     Month  Year  Anomaly_Qlog       DATE
# 46     11  1983      0.847118 1983-11-01
# 47     12  1983     -0.275393 1983-12-01
# 48      1  1984      1.595684 1984-01-01
# 49      2  1984      2.259184 1984-02-01
# 50      3  1984      1.123855 1984-03-01
# 51      4  1984     -0.272078 1984-04-01
# There are enough months in the past
# Target period: 11-1983 to 04-1984
# Target period includes two years
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 5
#     Month  Year  Anomaly_Qlog       DATE
# 47     12  1983     -0.275393 1983-12-01
# 48      1  1984      1.595684 1984-01-01
# 49      2  1984      2.259184 1984-02-01
# 50      3  1984      1.123855 1984-03-01
# 51      4  1984     -0.272078 1984-04-01
# 52      5  1984      0.460168 1984-05-01
# There are enough months in the past
# Target period: 12-1983 to 05-1984
# Target period includes two years
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 6
#     Month  Year  Anomaly_Qlog       DATE
# 48      1  1984      1.595684 1984-01-01
# 49      2  1984      2.259184 1984-02-01
# 50      3  1984      1.123855 1984-03-01
# 51      4  1984     -0.272078 1984-04-01
# 52      5  1984      0.460168 1984-05-01
# 53      6  1984      0.978806 1984-06-01
# There are enough months in the past
# Target period: 01-1984 to 06-1984
# Target period includes only one year
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 7
#     Month  Year  Anomaly_Qlog       DATE
# 49      2  1984      2.259184 1984-02-01
# 50      3  1984      1.123855 1984-03-01
# 51      4  1984     -0.272078 1984-04-01
# 52      5  1984      0.460168 1984-05-01
# 53      6  1984      0.978806 1984-06-01
# 54      7  1984      1.561809 1984-07-01
# There are enough months in the past
# Target period: 02-1984 to 07-1984
# Target period includes only one year
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 8
#     Month  Year  Anomaly_Qlog       DATE
# 50      3  1984      1.123855 1984-03-01
# 51      4  1984     -0.272078 1984-04-01
# 52      5  1984      0.460168 1984-05-01
# 53      6  1984      0.978806 1984-06-01
# 54      7  1984      1.561809 1984-07-01
# 55      8  1984           NaN 1984-08-01
# There are enough months in the past
# Target period: 03-1984 to 08-1984
# Target period includes only one year
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 9
#     Month  Year  Anomaly_Qlog       DATE
# 51      4  1984     -0.272078 1984-04-01
# 52      5  1984      0.460168 1984-05-01
# 53      6  1984      0.978806 1984-06-01
# 54      7  1984      1.561809 1984-07-01
# 55      8  1984           NaN 1984-08-01
# 56      9  1984     -0.010080 1984-09-01
# There are enough months in the past
# Target period: 04-1984 to 09-1984
# Target period includes only one year
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 10
#     Month  Year  Anomaly_Qlog       DATE
# 52      5  1984      0.460168 1984-05-01
# 53      6  1984      0.978806 1984-06-01
# 54      7  1984      1.561809 1984-07-01
# 55      8  1984           NaN 1984-08-01
# 56      9  1984     -0.010080 1984-09-01
# 57     10  1984      0.231029 1984-10-01
# There are enough months in the past
# Target period: 05-1984 to 10-1984
# Target period includes only one year
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 11
#     Month  Year  Anomaly_Qlog       DATE
# 53      6  1984      0.978806 1984-06-01
# 54      7  1984      1.561809 1984-07-01
# 55      8  1984           NaN 1984-08-01
# 56      9  1984     -0.010080 1984-09-01
# 57     10  1984      0.231029 1984-10-01
# 58     11  1984      0.809480 1984-11-01
# There are enough months in the past
# Target period: 06-1984 to 11-1984
# Target period includes only one year
#
# Dropping year: 1984  - get series for analysis.
# Year: 1984 - End-Month of observation: 12
#     Month  Year  Anomaly_Qlog       DATE
# 54      7  1984      1.561809 1984-07-01
# 55      8  1984           NaN 1984-08-01
# 56      9  1984     -0.010080 1984-09-01
# 57     10  1984      0.231029 1984-10-01
# 58     11  1984      0.809480 1984-11-01
# 59     12  1984     -1.162990 1984-12-01
# There are enough months in the past
# Target period: 07-1984 to 12-1984
# Target period includes only one year
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 1
#     Month  Year  Anomaly_Qlog       DATE
# 55      8  1984           NaN 1984-08-01
# 56      9  1984     -0.010080 1984-09-01
# 57     10  1984      0.231029 1984-10-01
# 58     11  1984      0.809480 1984-11-01
# 59     12  1984     -1.162990 1984-12-01
# 60      1  1985     -0.569929 1985-01-01
# There are enough months in the past
# Target period: 08-1984 to 01-1985
# Target period includes two years
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 2
#     Month  Year  Anomaly_Qlog       DATE
# 56      9  1984     -0.010080 1984-09-01
# 57     10  1984      0.231029 1984-10-01
# 58     11  1984      0.809480 1984-11-01
# 59     12  1984     -1.162990 1984-12-01
# 60      1  1985     -0.569929 1985-01-01
# 61      2  1985     -1.246188 1985-02-01
# There are enough months in the past
# Target period: 09-1984 to 02-1985
# Target period includes two years
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 3
#     Month  Year  Anomaly_Qlog       DATE
# 57     10  1984      0.231029 1984-10-01
# 58     11  1984      0.809480 1984-11-01
# 59     12  1984     -1.162990 1984-12-01
# 60      1  1985     -0.569929 1985-01-01
# 61      2  1985     -1.246188 1985-02-01
# 62      3  1985      0.667133 1985-03-01
# There are enough months in the past
# Target period: 10-1984 to 03-1985
# Target period includes two years
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 4
#     Month  Year  Anomaly_Qlog       DATE
# 58     11  1984      0.809480 1984-11-01
# 59     12  1984     -1.162990 1984-12-01
# 60      1  1985     -0.569929 1985-01-01
# 61      2  1985     -1.246188 1985-02-01
# 62      3  1985      0.667133 1985-03-01
# 63      4  1985      0.587747 1985-04-01
# There are enough months in the past
# Target period: 11-1984 to 04-1985
# Target period includes two years
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 5
#     Month  Year  Anomaly_Qlog       DATE
# 59     12  1984     -1.162990 1984-12-01
# 60      1  1985     -0.569929 1985-01-01
# 61      2  1985     -1.246188 1985-02-01
# 62      3  1985      0.667133 1985-03-01
# 63      4  1985      0.587747 1985-04-01
# 64      5  1985      0.516957 1985-05-01
# There are enough months in the past
# Target period: 12-1984 to 05-1985
# Target period includes two years
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 6
#     Month  Year  Anomaly_Qlog       DATE
# 60      1  1985     -0.569929 1985-01-01
# 61      2  1985     -1.246188 1985-02-01
# 62      3  1985      0.667133 1985-03-01
# 63      4  1985      0.587747 1985-04-01
# 64      5  1985      0.516957 1985-05-01
# 65      6  1985      0.530937 1985-06-01
# There are enough months in the past
# Target period: 01-1985 to 06-1985
# Target period includes only one year
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 7
#     Month  Year  Anomaly_Qlog       DATE
# 61      2  1985     -1.246188 1985-02-01
# 62      3  1985      0.667133 1985-03-01
# 63      4  1985      0.587747 1985-04-01
# 64      5  1985      0.516957 1985-05-01
# 65      6  1985      0.530937 1985-06-01
# 66      7  1985      0.633409 1985-07-01
# There are enough months in the past
# Target period: 02-1985 to 07-1985
# Target period includes only one year
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 8
#     Month  Year  Anomaly_Qlog       DATE
# 62      3  1985      0.667133 1985-03-01
# 63      4  1985      0.587747 1985-04-01
# 64      5  1985      0.516957 1985-05-01
# 65      6  1985      0.530937 1985-06-01
# 66      7  1985      0.633409 1985-07-01
# 67      8  1985      0.220850 1985-08-01
# There are enough months in the past
# Target period: 03-1985 to 08-1985
# Target period includes only one year
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 9
#     Month  Year  Anomaly_Qlog       DATE
# 63      4  1985      0.587747 1985-04-01
# 64      5  1985      0.516957 1985-05-01
# 65      6  1985      0.530937 1985-06-01
# 66      7  1985      0.633409 1985-07-01
# 67      8  1985      0.220850 1985-08-01
# 68      9  1985      0.475918 1985-09-01
# There are enough months in the past
# Target period: 04-1985 to 09-1985
# Target period includes only one year
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 10
#     Month  Year  Anomaly_Qlog       DATE
# 64      5  1985      0.516957 1985-05-01
# 65      6  1985      0.530937 1985-06-01
# 66      7  1985      0.633409 1985-07-01
# 67      8  1985      0.220850 1985-08-01
# 68      9  1985      0.475918 1985-09-01
# 69     10  1985      0.671122 1985-10-01
# There are enough months in the past
# Target period: 05-1985 to 10-1985
# Target period includes only one year
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 11
#     Month  Year  Anomaly_Qlog       DATE
# 65      6  1985      0.530937 1985-06-01
# 66      7  1985      0.633409 1985-07-01
# 67      8  1985      0.220850 1985-08-01
# 68      9  1985      0.475918 1985-09-01
# 69     10  1985      0.671122 1985-10-01
# 70     11  1985      0.336701 1985-11-01
# There are enough months in the past
# Target period: 06-1985 to 11-1985
# Target period includes only one year
#
# Dropping year: 1985  - get series for analysis.
# Year: 1985 - End-Month of observation: 12
#     Month  Year  Anomaly_Qlog       DATE
# 66      7  1985      0.633409 1985-07-01
# 67      8  1985      0.220850 1985-08-01
# 68      9  1985      0.475918 1985-09-01
# 69     10  1985      0.671122 1985-10-01
# 70     11  1985      0.336701 1985-11-01
# 71     12  1985     -0.915141 1985-12-01
# There are enough months in the past
# Target period: 07-1985 to 12-1985
# Target period includes only one year
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 1
#     Month  Year  Anomaly_Qlog       DATE
# 67      8  1985      0.220850 1985-08-01
# 68      9  1985      0.475918 1985-09-01
# 69     10  1985      0.671122 1985-10-01
# 70     11  1985      0.336701 1985-11-01
# 71     12  1985     -0.915141 1985-12-01
# 72      1  1986      0.060480 1986-01-01
# There are enough months in the past
# Target period: 08-1985 to 01-1986
# Target period includes two years
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 2
#     Month  Year  Anomaly_Qlog       DATE
# 68      9  1985      0.475918 1985-09-01
# 69     10  1985      0.671122 1985-10-01
# 70     11  1985      0.336701 1985-11-01
# 71     12  1985     -0.915141 1985-12-01
# 72      1  1986      0.060480 1986-01-01
# 73      2  1986     -0.407393 1986-02-01
# There are enough months in the past
# Target period: 09-1985 to 02-1986
# Target period includes two years
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 3
#     Month  Year  Anomaly_Qlog       DATE
# 69     10  1985      0.671122 1985-10-01
# 70     11  1985      0.336701 1985-11-01
# 71     12  1985     -0.915141 1985-12-01
# 72      1  1986      0.060480 1986-01-01
# 73      2  1986     -0.407393 1986-02-01
# 74      3  1986     -1.002581 1986-03-01
# There are enough months in the past
# Target period: 10-1985 to 03-1986
# Target period includes two years
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 4
#     Month  Year  Anomaly_Qlog       DATE
# 70     11  1985      0.336701 1985-11-01
# 71     12  1985     -0.915141 1985-12-01
# 72      1  1986      0.060480 1986-01-01
# 73      2  1986     -0.407393 1986-02-01
# 74      3  1986     -1.002581 1986-03-01
# 75      4  1986     -0.743722 1986-04-01
# There are enough months in the past
# Target period: 11-1985 to 04-1986
# Target period includes two years
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 5
#     Month  Year  Anomaly_Qlog       DATE
# 71     12  1985     -0.915141 1985-12-01
# 72      1  1986      0.060480 1986-01-01
# 73      2  1986     -0.407393 1986-02-01
# 74      3  1986     -1.002581 1986-03-01
# 75      4  1986     -0.743722 1986-04-01
# 76      5  1986      0.075766 1986-05-01
# There are enough months in the past
# Target period: 12-1985 to 05-1986
# Target period includes two years
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 6
#     Month  Year  Anomaly_Qlog       DATE
# 72      1  1986      0.060480 1986-01-01
# 73      2  1986     -0.407393 1986-02-01
# 74      3  1986     -1.002581 1986-03-01
# 75      4  1986     -0.743722 1986-04-01
# 76      5  1986      0.075766 1986-05-01
# 77      6  1986      0.359025 1986-06-01
# There are enough months in the past
# Target period: 01-1986 to 06-1986
# Target period includes only one year
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 7
#     Month  Year  Anomaly_Qlog       DATE
# 73      2  1986     -0.407393 1986-02-01
# 74      3  1986     -1.002581 1986-03-01
# 75      4  1986     -0.743722 1986-04-01
# 76      5  1986      0.075766 1986-05-01
# 77      6  1986      0.359025 1986-06-01
# 78      7  1986      0.125589 1986-07-01
# There are enough months in the past
# Target period: 02-1986 to 07-1986
# Target period includes only one year
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 8
#     Month  Year  Anomaly_Qlog       DATE
# 74      3  1986     -1.002581 1986-03-01
# 75      4  1986     -0.743722 1986-04-01
# 76      5  1986      0.075766 1986-05-01
# 77      6  1986      0.359025 1986-06-01
# 78      7  1986      0.125589 1986-07-01
# 79      8  1986      1.386902 1986-08-01
# There are enough months in the past
# Target period: 03-1986 to 08-1986
# Target period includes only one year
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 9
#     Month  Year  Anomaly_Qlog       DATE
# 75      4  1986     -0.743722 1986-04-01
# 76      5  1986      0.075766 1986-05-01
# 77      6  1986      0.359025 1986-06-01
# 78      7  1986      0.125589 1986-07-01
# 79      8  1986      1.386902 1986-08-01
# 80      9  1986      1.003092 1986-09-01
# There are enough months in the past
# Target period: 04-1986 to 09-1986
# Target period includes only one year
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 10
#     Month  Year  Anomaly_Qlog       DATE
# 76      5  1986      0.075766 1986-05-01
# 77      6  1986      0.359025 1986-06-01
# 78      7  1986      0.125589 1986-07-01
# 79      8  1986      1.386902 1986-08-01
# 80      9  1986      1.003092 1986-09-01
# 81     10  1986      0.774743 1986-10-01
# There are enough months in the past
# Target period: 05-1986 to 10-1986
# Target period includes only one year
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 11
#     Month  Year  Anomaly_Qlog       DATE
# 77      6  1986      0.359025 1986-06-01
# 78      7  1986      0.125589 1986-07-01
# 79      8  1986      1.386902 1986-08-01
# 80      9  1986      1.003092 1986-09-01
# 81     10  1986      0.774743 1986-10-01
# 82     11  1986      1.217815 1986-11-01
# There are enough months in the past
# Target period: 06-1986 to 11-1986
# Target period includes only one year
#
# Dropping year: 1986  - get series for analysis.
# Year: 1986 - End-Month of observation: 12
#     Month  Year  Anomaly_Qlog       DATE
# 78      7  1986      0.125589 1986-07-01
# 79      8  1986      1.386902 1986-08-01
# 80      9  1986      1.003092 1986-09-01
# 81     10  1986      0.774743 1986-10-01
# 82     11  1986      1.217815 1986-11-01
# 83     12  1986      0.701937 1986-12-01
# There are enough months in the past
# Target period: 07-1986 to 12-1986
# Target period includes only one year
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 1
#     Month  Year  Anomaly_Qlog       DATE
# 79      8  1986      1.386902 1986-08-01
# 80      9  1986      1.003092 1986-09-01
# 81     10  1986      0.774743 1986-10-01
# 82     11  1986      1.217815 1986-11-01
# 83     12  1986      0.701937 1986-12-01
# 84      1  1987           NaN 1987-01-01
# There are enough months in the past
# Target period: 08-1986 to 01-1987
# Target period includes two years
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 2
#     Month  Year  Anomaly_Qlog       DATE
# 80      9  1986      1.003092 1986-09-01
# 81     10  1986      0.774743 1986-10-01
# 82     11  1986      1.217815 1986-11-01
# 83     12  1986      0.701937 1986-12-01
# 84      1  1987           NaN 1987-01-01
# 85      2  1987           NaN 1987-02-01
# There are enough months in the past
# Target period: 09-1986 to 02-1987
# Target period includes two years
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 3
#     Month  Year  Anomaly_Qlog       DATE
# 81     10  1986      0.774743 1986-10-01
# 82     11  1986      1.217815 1986-11-01
# 83     12  1986      0.701937 1986-12-01
# 84      1  1987           NaN 1987-01-01
# 85      2  1987           NaN 1987-02-01
# 86      3  1987           NaN 1987-03-01
# There are enough months in the past
# Target period: 10-1986 to 03-1987
# Target period includes two years
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 4
#     Month  Year  Anomaly_Qlog       DATE
# 82     11  1986      1.217815 1986-11-01
# 83     12  1986      0.701937 1986-12-01
# 84      1  1987           NaN 1987-01-01
# 85      2  1987           NaN 1987-02-01
# 86      3  1987           NaN 1987-03-01
# 87      4  1987           NaN 1987-04-01
# There are enough months in the past
# Target period: 11-1986 to 04-1987
# Target period includes two years
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 5
#     Month  Year  Anomaly_Qlog       DATE
# 83     12  1986      0.701937 1986-12-01
# 84      1  1987           NaN 1987-01-01
# 85      2  1987           NaN 1987-02-01
# 86      3  1987           NaN 1987-03-01
# 87      4  1987           NaN 1987-04-01
# 88      5  1987           NaN 1987-05-01
# There are enough months in the past
# Target period: 12-1986 to 05-1987
# Target period includes two years
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 6
#     Month  Year  Anomaly_Qlog       DATE
# 84      1  1987           NaN 1987-01-01
# 85      2  1987           NaN 1987-02-01
# 86      3  1987           NaN 1987-03-01
# 87      4  1987           NaN 1987-04-01
# 88      5  1987           NaN 1987-05-01
# 89      6  1987           NaN 1987-06-01
# There are enough months in the past
# Target period: 01-1987 to 06-1987
# Target period includes only one year
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 7
#     Month  Year  Anomaly_Qlog       DATE
# 85      2  1987           NaN 1987-02-01
# 86      3  1987           NaN 1987-03-01
# 87      4  1987           NaN 1987-04-01
# 88      5  1987           NaN 1987-05-01
# 89      6  1987           NaN 1987-06-01
# 90      7  1987           NaN 1987-07-01
# There are enough months in the past
# Target period: 02-1987 to 07-1987
# Target period includes only one year
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 8
#     Month  Year  Anomaly_Qlog       DATE
# 86      3  1987           NaN 1987-03-01
# 87      4  1987           NaN 1987-04-01
# 88      5  1987           NaN 1987-05-01
# 89      6  1987           NaN 1987-06-01
# 90      7  1987           NaN 1987-07-01
# 91      8  1987           NaN 1987-08-01
# There are enough months in the past
# Target period: 03-1987 to 08-1987
# Target period includes only one year
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 9
#     Month  Year  Anomaly_Qlog       DATE
# 87      4  1987           NaN 1987-04-01
# 88      5  1987           NaN 1987-05-01
# 89      6  1987           NaN 1987-06-01
# 90      7  1987           NaN 1987-07-01
# 91      8  1987           NaN 1987-08-01
# 92      9  1987           NaN 1987-09-01
# There are enough months in the past
# Target period: 04-1987 to 09-1987
# Target period includes only one year
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 10
#     Month  Year  Anomaly_Qlog       DATE
# 88      5  1987           NaN 1987-05-01
# 89      6  1987           NaN 1987-06-01
# 90      7  1987           NaN 1987-07-01
# 91      8  1987           NaN 1987-08-01
# 92      9  1987           NaN 1987-09-01
# 93     10  1987           NaN 1987-10-01
# There are enough months in the past
# Target period: 05-1987 to 10-1987
# Target period includes only one year
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 11
#     Month  Year  Anomaly_Qlog       DATE
# 89      6  1987           NaN 1987-06-01
# 90      7  1987           NaN 1987-07-01
# 91      8  1987           NaN 1987-08-01
# 92      9  1987           NaN 1987-09-01
# 93     10  1987           NaN 1987-10-01
# 94     11  1987           NaN 1987-11-01
# There are enough months in the past
# Target period: 06-1987 to 11-1987
# Target period includes only one year
#
# Dropping year: 1987  - get series for analysis.
# Year: 1987 - End-Month of observation: 12
#     Month  Year  Anomaly_Qlog       DATE
# 90      7  1987           NaN 1987-07-01
# 91      8  1987           NaN 1987-08-01
# 92      9  1987           NaN 1987-09-01
# 93     10  1987           NaN 1987-10-01
# 94     11  1987           NaN 1987-11-01
# 95     12  1987           NaN 1987-12-01
# There are enough months in the past
# Target period: 07-1987 to 12-1987
# Target period includes only one year
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 1
#     Month  Year  Anomaly_Qlog       DATE
# 91      8  1987           NaN 1987-08-01
# 92      9  1987           NaN 1987-09-01
# 93     10  1987           NaN 1987-10-01
# 94     11  1987           NaN 1987-11-01
# 95     12  1987           NaN 1987-12-01
# 96      1  1988      1.695788 1988-01-01
# There are enough months in the past
# Target period: 08-1987 to 01-1988
# Target period includes two years
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 2
#     Month  Year  Anomaly_Qlog       DATE
# 92      9  1987           NaN 1987-09-01
# 93     10  1987           NaN 1987-10-01
# 94     11  1987           NaN 1987-11-01
# 95     12  1987           NaN 1987-12-01
# 96      1  1988      1.695788 1988-01-01
# 97      2  1988      0.119670 1988-02-01
# There are enough months in the past
# Target period: 09-1987 to 02-1988
# Target period includes two years
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 3
#     Month  Year  Anomaly_Qlog       DATE
# 93     10  1987           NaN 1987-10-01
# 94     11  1987           NaN 1987-11-01
# 95     12  1987           NaN 1987-12-01
# 96      1  1988      1.695788 1988-01-01
# 97      2  1988      0.119670 1988-02-01
# 98      3  1988      1.681609 1988-03-01
# There are enough months in the past
# Target period: 10-1987 to 03-1988
# Target period includes two years
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 4
#     Month  Year  Anomaly_Qlog       DATE
# 94     11  1987           NaN 1987-11-01
# 95     12  1987           NaN 1987-12-01
# 96      1  1988      1.695788 1988-01-01
# 97      2  1988      0.119670 1988-02-01
# 98      3  1988      1.681609 1988-03-01
# 99      4  1988      0.717188 1988-04-01
# There are enough months in the past
# Target period: 11-1987 to 04-1988
# Target period includes two years
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 5
#      Month  Year  Anomaly_Qlog       DATE
# 95      12  1987           NaN 1987-12-01
# 96       1  1988      1.695788 1988-01-01
# 97       2  1988      0.119670 1988-02-01
# 98       3  1988      1.681609 1988-03-01
# 99       4  1988      0.717188 1988-04-01
# 100      5  1988     -0.967284 1988-05-01
# There are enough months in the past
# Target period: 12-1987 to 05-1988
# Target period includes two years
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 6
#      Month  Year  Anomaly_Qlog       DATE
# 96       1  1988      1.695788 1988-01-01
# 97       2  1988      0.119670 1988-02-01
# 98       3  1988      1.681609 1988-03-01
# 99       4  1988      0.717188 1988-04-01
# 100      5  1988     -0.967284 1988-05-01
# 101      6  1988     -1.301700 1988-06-01
# There are enough months in the past
# Target period: 01-1988 to 06-1988
# Target period includes only one year
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 7
#      Month  Year  Anomaly_Qlog       DATE
# 97       2  1988      0.119670 1988-02-01
# 98       3  1988      1.681609 1988-03-01
# 99       4  1988      0.717188 1988-04-01
# 100      5  1988     -0.967284 1988-05-01
# 101      6  1988     -1.301700 1988-06-01
# 102      7  1988     -0.615400 1988-07-01
# There are enough months in the past
# Target period: 02-1988 to 07-1988
# Target period includes only one year
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 8
#      Month  Year  Anomaly_Qlog       DATE
# 98       3  1988      1.681609 1988-03-01
# 99       4  1988      0.717188 1988-04-01
# 100      5  1988     -0.967284 1988-05-01
# 101      6  1988     -1.301700 1988-06-01
# 102      7  1988     -0.615400 1988-07-01
# 103      8  1988     -0.485248 1988-08-01
# There are enough months in the past
# Target period: 03-1988 to 08-1988
# Target period includes only one year
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 9
#      Month  Year  Anomaly_Qlog       DATE
# 99       4  1988      0.717188 1988-04-01
# 100      5  1988     -0.967284 1988-05-01
# 101      6  1988     -1.301700 1988-06-01
# 102      7  1988     -0.615400 1988-07-01
# 103      8  1988     -0.485248 1988-08-01
# 104      9  1988     -1.031575 1988-09-01
# There are enough months in the past
# Target period: 04-1988 to 09-1988
# Target period includes only one year
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 10
#      Month  Year  Anomaly_Qlog       DATE
# 100      5  1988     -0.967284 1988-05-01
# 101      6  1988     -1.301700 1988-06-01
# 102      7  1988     -0.615400 1988-07-01
# 103      8  1988     -0.485248 1988-08-01
# 104      9  1988     -1.031575 1988-09-01
# 105     10  1988     -1.142164 1988-10-01
# There are enough months in the past
# Target period: 05-1988 to 10-1988
# Target period includes only one year
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 11
#      Month  Year  Anomaly_Qlog       DATE
# 101      6  1988     -1.301700 1988-06-01
# 102      7  1988     -0.615400 1988-07-01
# 103      8  1988     -0.485248 1988-08-01
# 104      9  1988     -1.031575 1988-09-01
# 105     10  1988     -1.142164 1988-10-01
# 106     11  1988     -0.726399 1988-11-01
# There are enough months in the past
# Target period: 06-1988 to 11-1988
# Target period includes only one year
#
# Dropping year: 1988  - get series for analysis.
# Year: 1988 - End-Month of observation: 12
#      Month  Year  Anomaly_Qlog       DATE
# 102      7  1988     -0.615400 1988-07-01
# 103      8  1988     -0.485248 1988-08-01
# 104      9  1988     -1.031575 1988-09-01
# 105     10  1988     -1.142164 1988-10-01
# 106     11  1988     -0.726399 1988-11-01
# 107     12  1988     -1.251198 1988-12-01
# There are enough months in the past
# Target period: 07-1988 to 12-1988
# Target period includes only one year
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 1
#      Month  Year  Anomaly_Qlog       DATE
# 103      8  1988     -0.485248 1988-08-01
# 104      9  1988     -1.031575 1988-09-01
# 105     10  1988     -1.142164 1988-10-01
# 106     11  1988     -0.726399 1988-11-01
# 107     12  1988     -1.251198 1988-12-01
# 108      1  1989     -0.609378 1989-01-01
# There are enough months in the past
# Target period: 08-1988 to 01-1989
# Target period includes two years
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 2
#      Month  Year  Anomaly_Qlog       DATE
# 104      9  1988     -1.031575 1988-09-01
# 105     10  1988     -1.142164 1988-10-01
# 106     11  1988     -0.726399 1988-11-01
# 107     12  1988     -1.251198 1988-12-01
# 108      1  1989     -0.609378 1989-01-01
# 109      2  1989     -1.349524 1989-02-01
# There are enough months in the past
# Target period: 09-1988 to 02-1989
# Target period includes two years
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 3
#      Month  Year  Anomaly_Qlog       DATE
# 105     10  1988     -1.142164 1988-10-01
# 106     11  1988     -0.726399 1988-11-01
# 107     12  1988     -1.251198 1988-12-01
# 108      1  1989     -0.609378 1989-01-01
# 109      2  1989     -1.349524 1989-02-01
# 110      3  1989     -1.100457 1989-03-01
# There are enough months in the past
# Target period: 10-1988 to 03-1989
# Target period includes two years
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 4
#      Month  Year  Anomaly_Qlog       DATE
# 106     11  1988     -0.726399 1988-11-01
# 107     12  1988     -1.251198 1988-12-01
# 108      1  1989     -0.609378 1989-01-01
# 109      2  1989     -1.349524 1989-02-01
# 110      3  1989     -1.100457 1989-03-01
# 111      4  1989     -1.221652 1989-04-01
# There are enough months in the past
# Target period: 11-1988 to 04-1989
# Target period includes two years
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 5
#      Month  Year  Anomaly_Qlog       DATE
# 107     12  1988     -1.251198 1988-12-01
# 108      1  1989     -0.609378 1989-01-01
# 109      2  1989     -1.349524 1989-02-01
# 110      3  1989     -1.100457 1989-03-01
# 111      4  1989     -1.221652 1989-04-01
# 112      5  1989     -1.966323 1989-05-01
# There are enough months in the past
# Target period: 12-1988 to 05-1989
# Target period includes two years
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 6
#      Month  Year  Anomaly_Qlog       DATE
# 108      1  1989     -0.609378 1989-01-01
# 109      2  1989     -1.349524 1989-02-01
# 110      3  1989     -1.100457 1989-03-01
# 111      4  1989     -1.221652 1989-04-01
# 112      5  1989     -1.966323 1989-05-01
# 113      6  1989     -2.108455 1989-06-01
# There are enough months in the past
# Target period: 01-1989 to 06-1989
# Target period includes only one year
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 7
#      Month  Year  Anomaly_Qlog       DATE
# 109      2  1989     -1.349524 1989-02-01
# 110      3  1989     -1.100457 1989-03-01
# 111      4  1989     -1.221652 1989-04-01
# 112      5  1989     -1.966323 1989-05-01
# 113      6  1989     -2.108455 1989-06-01
# 114      7  1989     -1.530132 1989-07-01
# There are enough months in the past
# Target period: 02-1989 to 07-1989
# Target period includes only one year
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 8
#      Month  Year  Anomaly_Qlog       DATE
# 110      3  1989     -1.100457 1989-03-01
# 111      4  1989     -1.221652 1989-04-01
# 112      5  1989     -1.966323 1989-05-01
# 113      6  1989     -2.108455 1989-06-01
# 114      7  1989     -1.530132 1989-07-01
# 115      8  1989     -0.442800 1989-08-01
# There are enough months in the past
# Target period: 03-1989 to 08-1989
# Target period includes only one year
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 9
#      Month  Year  Anomaly_Qlog       DATE
# 111      4  1989     -1.221652 1989-04-01
# 112      5  1989     -1.966323 1989-05-01
# 113      6  1989     -2.108455 1989-06-01
# 114      7  1989     -1.530132 1989-07-01
# 115      8  1989     -0.442800 1989-08-01
# 116      9  1989     -1.350103 1989-09-01
# There are enough months in the past
# Target period: 04-1989 to 09-1989
# Target period includes only one year
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 10
#      Month  Year  Anomaly_Qlog       DATE
# 112      5  1989     -1.966323 1989-05-01
# 113      6  1989     -2.108455 1989-06-01
# 114      7  1989     -1.530132 1989-07-01
# 115      8  1989     -0.442800 1989-08-01
# 116      9  1989     -1.350103 1989-09-01
# 117     10  1989     -1.737324 1989-10-01
# There are enough months in the past
# Target period: 05-1989 to 10-1989
# Target period includes only one year
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 11
#      Month  Year  Anomaly_Qlog       DATE
# 113      6  1989     -2.108455 1989-06-01
# 114      7  1989     -1.530132 1989-07-01
# 115      8  1989     -0.442800 1989-08-01
# 116      9  1989     -1.350103 1989-09-01
# 117     10  1989     -1.737324 1989-10-01
# 118     11  1989     -1.502100 1989-11-01
# There are enough months in the past
# Target period: 06-1989 to 11-1989
# Target period includes only one year
#
# Dropping year: 1989  - get series for analysis.
# Year: 1989 - End-Month of observation: 12
#      Month  Year  Anomaly_Qlog       DATE
# 114      7  1989     -1.530132 1989-07-01
# 115      8  1989     -0.442800 1989-08-01
# 116      9  1989     -1.350103 1989-09-01
# 117     10  1989     -1.737324 1989-10-01
# 118     11  1989     -1.502100 1989-11-01
# 119     12  1989     -0.235918 1989-12-01
# There are enough months in the past
# Target period: 07-1989 to 12-1989
# Target period includes only one year
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 1
#      Month  Year  Anomaly_Qlog       DATE
# 115      8  1989     -0.442800 1989-08-01
# 116      9  1989     -1.350103 1989-09-01
# 117     10  1989     -1.737324 1989-10-01
# 118     11  1989     -1.502100 1989-11-01
# 119     12  1989     -0.235918 1989-12-01
# 120      1  1990     -0.540918 1990-01-01
# There are enough months in the past
# Target period: 08-1989 to 01-1990
# Target period includes two years
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 2
#      Month  Year  Anomaly_Qlog       DATE
# 116      9  1989     -1.350103 1989-09-01
# 117     10  1989     -1.737324 1989-10-01
# 118     11  1989     -1.502100 1989-11-01
# 119     12  1989     -0.235918 1989-12-01
# 120      1  1990     -0.540918 1990-01-01
# 121      2  1990      0.599554 1990-02-01
# There are enough months in the past
# Target period: 09-1989 to 02-1990
# Target period includes two years
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 3
#      Month  Year  Anomaly_Qlog       DATE
# 117     10  1989     -1.737324 1989-10-01
# 118     11  1989     -1.502100 1989-11-01
# 119     12  1989     -0.235918 1989-12-01
# 120      1  1990     -0.540918 1990-01-01
# 121      2  1990      0.599554 1990-02-01
# 122      3  1990      0.285230 1990-03-01
# There are enough months in the past
# Target period: 10-1989 to 03-1990
# Target period includes two years
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 4
#      Month  Year  Anomaly_Qlog       DATE
# 118     11  1989     -1.502100 1989-11-01
# 119     12  1989     -0.235918 1989-12-01
# 120      1  1990     -0.540918 1990-01-01
# 121      2  1990      0.599554 1990-02-01
# 122      3  1990      0.285230 1990-03-01
# 123      4  1990      1.923675 1990-04-01
# There are enough months in the past
# Target period: 11-1989 to 04-1990
# Target period includes two years
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 5
#      Month  Year  Anomaly_Qlog       DATE
# 119     12  1989     -0.235918 1989-12-01
# 120      1  1990     -0.540918 1990-01-01
# 121      2  1990      0.599554 1990-02-01
# 122      3  1990      0.285230 1990-03-01
# 123      4  1990      1.923675 1990-04-01
# 124      5  1990     -0.170332 1990-05-01
# There are enough months in the past
# Target period: 12-1989 to 05-1990
# Target period includes two years
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 6
#      Month  Year  Anomaly_Qlog       DATE
# 120      1  1990     -0.540918 1990-01-01
# 121      2  1990      0.599554 1990-02-01
# 122      3  1990      0.285230 1990-03-01
# 123      4  1990      1.923675 1990-04-01
# 124      5  1990     -0.170332 1990-05-01
# 125      6  1990      0.048584 1990-06-01
# There are enough months in the past
# Target period: 01-1990 to 06-1990
# Target period includes only one year
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 7
#      Month  Year  Anomaly_Qlog       DATE
# 121      2  1990      0.599554 1990-02-01
# 122      3  1990      0.285230 1990-03-01
# 123      4  1990      1.923675 1990-04-01
# 124      5  1990     -0.170332 1990-05-01
# 125      6  1990      0.048584 1990-06-01
# 126      7  1990     -1.538323 1990-07-01
# There are enough months in the past
# Target period: 02-1990 to 07-1990
# Target period includes only one year
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 8
#      Month  Year  Anomaly_Qlog       DATE
# 122      3  1990      0.285230 1990-03-01
# 123      4  1990      1.923675 1990-04-01
# 124      5  1990     -0.170332 1990-05-01
# 125      6  1990      0.048584 1990-06-01
# 126      7  1990     -1.538323 1990-07-01
# 127      8  1990     -2.189276 1990-08-01
# There are enough months in the past
# Target period: 03-1990 to 08-1990
# Target period includes only one year
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 9
#      Month  Year  Anomaly_Qlog       DATE
# 123      4  1990      1.923675 1990-04-01
# 124      5  1990     -0.170332 1990-05-01
# 125      6  1990      0.048584 1990-06-01
# 126      7  1990     -1.538323 1990-07-01
# 127      8  1990     -2.189276 1990-08-01
# 128      9  1990     -1.351109 1990-09-01
# There are enough months in the past
# Target period: 04-1990 to 09-1990
# Target period includes only one year
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 10
#      Month  Year  Anomaly_Qlog       DATE
# 124      5  1990     -0.170332 1990-05-01
# 125      6  1990      0.048584 1990-06-01
# 126      7  1990     -1.538323 1990-07-01
# 127      8  1990     -2.189276 1990-08-01
# 128      9  1990     -1.351109 1990-09-01
# 129     10  1990     -0.008010 1990-10-01
# There are enough months in the past
# Target period: 05-1990 to 10-1990
# Target period includes only one year
#
# Dropping year: 1990  - get series for analysis.
# Year: 1990 - End-Month of observation: 11
#      Month  Year  Anomaly_Qlog       DATE
# 125      6  1990      0.048584 1990-06-01
# 126      7  1990     -1.538323 1990-07-01
# 127      8  1990     -2.189276 1990-08-01
# 128      9  1990     -1.351109 1990-09-01
# 129     10  1990     -0.008010 1990-10-01
# 130     11  1990      0.655603 1990-11-01
# There are enough months in the past
# Target period: 06-1990 to 11-1990
# Target period includes only one year
#
# Year: 1990 - End-Month of observation: 12
#      Month  Year  Anomaly_Qlog       DATE
# 126      7  1990     -1.538323 1990-07-01
# 127      8  1990     -2.189276 1990-08-01
# 128      9  1990     -1.351109 1990-09-01
# 129     10  1990     -0.008010 1990-10-01
# 130     11  1990      0.655603 1990-11-01
# 131     12  1990      1.268143 1990-12-01
# There are enough months in the past
# Target period: 07-1990 to 12-1990
# Target period includes only one year

# %%
RESULTS = pd.DataFrame()
RESULTS['MONTH_PRED'] = MON_PRED
RESULTS['YEAR_PRED'] = ANO_PRED
RESULTS['MONTH_TARG'] = MON_TARG
RESULTS['YEAR_TARG'] = ANO_TARG
RESULTS['RMSE'] = RMSE
RESULTS['TARG'] = TARG
RESULTS['PRED'] = PRED
RESULTS['OBS_ANOM'] = OBS_ANOM
RESULTS['MEAN_ANOM_HIND'] = MEAN_ANOM_HIND
RESULTS['STD_ANOM_HIND'] = STD_ANOM_HIND
RESULTS['Q1_ANOM_HIND'] = Q1_ANOM_HIND
RESULTS['Q3_ANOM_HIND'] = Q3_ANOM_HIND

# %%
RESULTS.iloc[66:80]
# Out:
#     MONTH_PRED  YEAR_PRED             MONTH_TARG  YEAR_TARG    RMSE  \
# 66           1       1981  [7, 8, 9, 10, 11, 12]  1987-1987     NaN
# 67           1       1981  [7, 8, 9, 10, 11, 12]  1988-1988  1.4123
# 68           1       1981  [7, 8, 9, 10, 11, 12]  1989-1989  1.5856
# 69           1       1981  [7, 8, 9, 10, 11, 12]  1990-1990     NaN
# 70           2       1981  [8, 9, 10, 11, 12, 1]  1981-1982  0.9869
# 71           2       1981  [8, 9, 10, 11, 12, 1]  1982-1983     NaN
# 72           2       1981  [8, 9, 10, 11, 12, 1]  1983-1984  1.2754
# 73           2       1981  [8, 9, 10, 11, 12, 1]  1984-1985     NaN
# 74           2       1981  [8, 9, 10, 11, 12, 1]  1985-1986  1.0182
# 75           2       1981  [8, 9, 10, 11, 12, 1]  1986-1987     NaN
# 76           2       1981  [8, 9, 10, 11, 12, 1]  1987-1988     NaN
# 77           2       1981  [8, 9, 10, 11, 12, 1]  1988-1989  1.3798
# 78           2       1981  [8, 9, 10, 11, 12, 1]  1989-1990  1.3655
# 79           3       1981  [9, 10, 11, 12, 1, 2]  1981-1982  0.9849
#
#                                                  TARG  \
# 66  [0.68247, 0.10954, -0.35398, 0.5367, -0.33175,...
# 67  [0.68247, 0.10954, -0.35398, 0.5367, -0.33175,...
# 68  [0.68247, 0.10954, -0.35398, 0.5367, -0.33175,...
# 69  [0.68247, 0.10954, -0.35398, 0.5367, -0.33175,...
# 70  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 71  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 72  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 73  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 74  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 75  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 76  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 77  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 78  [0.10954, -0.35398, 0.5367, -0.33175, 1.29762,...
# 79  [-0.35398, 0.5367, -0.33175, 1.29762, 0.45825,...
#
#                                                  PRED  OBS_ANOM  \
# 66                     [nan, nan, nan, nan, nan, nan]       NaN
# 67  [-0.6154, -0.48525, -1.03157, -1.14216, -0.726...  -0.60938
# 68  [-1.53013, -0.4428, -1.3501, -1.73732, -1.5021...  -0.54092
# 69  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...       NaN
# 70  [0.41381, 0.61431, -0.67744, -1.30647, 0.57294...   0.16444
# 71        [0.23456, 0.47972, nan, nan, nan, -0.07843]       NaN
# 72  [0.75167, 1.5238, 1.35134, 0.84712, -0.27539, ...   2.25918
# 73  [nan, -0.01008, 0.23103, 0.80948, -1.16299, -0...       NaN
# 74  [0.22085, 0.47592, 0.67112, 0.3367, -0.91514, ...  -0.40739
# 75  [1.3869, 1.00309, 0.77474, 1.21781, 0.70194, nan]       NaN
# 76                 [nan, nan, nan, nan, nan, 1.69579]       NaN
# 77  [-0.48525, -1.03157, -1.14216, -0.7264, -1.251...  -1.34952
# 78  [-0.4428, -1.3501, -1.73732, -1.5021, -0.23592...   0.59955
# 79  [0.61431, -0.67744, -1.30647, 0.57294, -0.9071...  -0.47138
#
#     MEAN_ANOM_HIND  STD_ANOM_HIND  Q1_ANOM_HIND  Q3_ANOM_HIND
# 66       -0.098902       1.090611     -0.599910      0.027140
# 67       -0.098902       1.090611     -0.599910      0.027140
# 68       -0.098902       1.090611     -0.599910      0.027140
# 69       -0.098902       1.090611     -0.599910      0.027140
# 70        0.046575       1.065671     -0.300568      0.223171
# 71        0.046575       1.065671     -0.300568      0.223171
# 72        0.046575       1.065671     -0.300568      0.223171
# 73        0.046575       1.065671     -0.300568      0.223171
# 74        0.046575       1.065671     -0.300568      0.223171
# 75        0.046575       1.065671     -0.300568      0.223171
# 76        0.046575       1.065671     -0.300568      0.223171
# 77        0.046575       1.065671     -0.300568      0.223171
# 78        0.046575       1.065671     -0.300568      0.223171
# 79        0.130716       1.067735     -0.875094      0.957916

# %%
RESULTS.tail(10)
# Out:
#       MONTH_PRED  YEAR_PRED             MONTH_TARG  YEAR_TARG    RMSE  \
# 1210           1       1991  [7, 8, 9, 10, 11, 12]  1980-1980  1.4424
# 1211           1       1991  [7, 8, 9, 10, 11, 12]  1981-1981  1.7790
# 1212           1       1991  [7, 8, 9, 10, 11, 12]  1982-1982     NaN
# 1213           1       1991  [7, 8, 9, 10, 11, 12]  1983-1983  1.9468
# 1214           1       1991  [7, 8, 9, 10, 11, 12]  1984-1984     NaN
# 1215           1       1991  [7, 8, 9, 10, 11, 12]  1985-1985  1.7885
# 1216           1       1991  [7, 8, 9, 10, 11, 12]  1986-1986     NaN
# 1217           1       1991  [7, 8, 9, 10, 11, 12]  1987-1987     NaN
# 1218           1       1991  [7, 8, 9, 10, 11, 12]  1988-1988  1.4945
# 1219           1       1991  [7, 8, 9, 10, 11, 12]  1989-1989  1.4696
#
#                                                    TARG  \
# 1210  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1211  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1212  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1213  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1214  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1215  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1216  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1217  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1218  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
# 1219  [-1.53832, -2.18928, -1.35111, -0.00801, 0.655...
#
#                                                    PRED  OBS_ANOM  \
# 1210  [0.68247, 0.10954, -0.35398, 0.5367, -0.33175,...   0.45825
# 1211  [0.35065, 0.41381, 0.61431, -0.67744, -1.30647...  -0.90715
# 1212         [0.62003, 0.23456, 0.47972, nan, nan, nan]       NaN
# 1213  [-0.2901, 0.75167, 1.5238, 1.35134, 0.84712, -...   1.59568
# 1214  [1.56181, nan, -0.01008, 0.23103, 0.80948, -1....       NaN
# 1215  [0.63341, 0.22085, 0.47592, 0.67112, 0.3367, -...   0.06048
# 1216  [0.12559, 1.3869, 1.00309, 0.77474, 1.21781, 0...       NaN
# 1217                     [nan, nan, nan, nan, nan, nan]       NaN
# 1218  [-0.6154, -0.48525, -1.03157, -1.14216, -0.726...  -0.60938
# 1219  [-1.53013, -0.4428, -1.3501, -1.73732, -1.5021...  -0.54092
#
#       MEAN_ANOM_HIND  STD_ANOM_HIND  Q1_ANOM_HIND  Q3_ANOM_HIND
# 1210        0.012116       1.090847      -0.59991      0.362784
# 1211        0.012116       1.090847      -0.59991      0.362784
# 1212        0.012116       1.090847      -0.59991      0.362784
# 1213        0.012116       1.090847      -0.59991      0.362784
# 1214        0.012116       1.090847      -0.59991      0.362784
# 1215        0.012116       1.090847      -0.59991      0.362784
# 1216        0.012116       1.090847      -0.59991      0.362784
# 1217        0.012116       1.090847      -0.59991      0.362784
# 1218        0.012116       1.090847      -0.59991      0.362784
# 1219        0.012116       1.090847      -0.59991      0.362784

# %%
TTT = pd.DataFrame()
TTT['DATE'] = pd.date_range(datetime.date.today().replace(year=RESULTS.iloc[0]['YEAR_PRED'], month=RESULTS.iloc[0]['MONTH_PRED'], day=1),datetime.date.today().replace(year=RESULTS.iloc[-1]['YEAR_PRED'], month=RESULTS.iloc[-1]['MONTH_PRED'], day=1),freq='MS')
TTT['MONTH_PRED'] = pd.date_range(datetime.date.today().replace(year=RESULTS.iloc[0]['YEAR_PRED'], month=RESULTS['MONTH_PRED'][0], day=1),datetime.date.today().replace(year=RESULTS.iloc[-1]['YEAR_PRED'], month=RESULTS.iloc[-1]['MONTH_PRED'], day=1),freq='MS').month
TTT['YEAR_PRED'] = pd.date_range(datetime.date.today().replace(year=RESULTS.iloc[0]['YEAR_PRED'], month=RESULTS['MONTH_PRED'][0], day=1),datetime.date.today().replace(year=RESULTS.iloc[-1]['YEAR_PRED'], month=RESULTS.iloc[-1]['MONTH_PRED'], day=1),freq='MS').year
TTT['MONTH_PRED_cal'] = TTT['MONTH_PRED'].apply(lambda x: calendar.month_abbr[x])

# %%
TTT.tail(5)
# Out:
#           DATE  MONTH_PRED  YEAR_PRED MONTH_PRED_cal
# 122 1990-09-01           9       1990            Sep
# 123 1990-10-01          10       1990            Oct
# 124 1990-11-01          11       1990            Nov
# 125 1990-12-01          12       1990            Dec
# 126 1991-01-01           1       1991            Jan

# %%
best_n = 5
INDEX_best_n = []
RMSE_best_n = []
w_best_n = []
OBS_ANOM_best_n = []

MEAN_ANOM_HIND_best_n = []
STD_ANOM_HIND_best_n = []
Q1_ANOM_HIND_best_n = []
Q3_ANOM_HIND_best_n = []

for y in np.sort(TTT['YEAR_PRED'].unique()):
    #print(y)
    for m in np.sort(TTT['MONTH_PRED'].unique()):
        
        ## Get index observerved anomaly value series best n RMSE sorted
        AUX_1 = RESULTS.query('MONTH_PRED == @m & YEAR_PRED == @y').sort_values(by=['RMSE']).head(best_n).index
        AUX_2 = AUX_1.values.tolist()
        if AUX_2:
            INDEX_best_n.append(AUX_2)
        else:
            pass
        
        ## Get predicted anomaly value series best n RMSE sorted
        AUX_3 = RESULTS.query('MONTH_PRED == @m & YEAR_PRED == @y').sort_values(by=['RMSE']).head(best_n)
        AUX_4 = AUX_3['RMSE'].values.tolist()
#         AUX_5 = AUX_3['OBS_ANOM'].values.tolist()
        if AUX_4:
            RMSE_best_n.append(AUX_4)
            #Calculation of weights
            w_best_n.append(((1/np.array(AUX_4)) / (1/np.array(AUX_4)).sum()).round(6))
        else:
            pass

        ## Get observerved anomaly value series best n RMSE sorted
        AUX_5 = AUX_3['OBS_ANOM'].values.tolist()
        if AUX_5:
            OBS_ANOM_best_n.append(AUX_5)    
        else:
            pass
        
        ## Get mean anomaly of hindcast series best n RMSE sorted
        AUX_6 = AUX_3['MEAN_ANOM_HIND'].values.tolist()              
        if AUX_6:
            MEAN_ANOM_HIND_best_n.append(AUX_6[0])    
        else:
            pass
        
        ## Get standard deviation anomaly of hindcast series best n RMSE sorted
        AUX_7 = AUX_3['STD_ANOM_HIND'].values.tolist()       
        if AUX_7:
            STD_ANOM_HIND_best_n.append(AUX_7[0])    
        else:
            pass        
        
        ## Get Q1 anomaly of hindcast series best n RMSE sorted
        AUX_8 = AUX_3['Q1_ANOM_HIND'].values.tolist()       
        if AUX_8:
            Q1_ANOM_HIND_best_n.append(AUX_8[0])    
        else:
            pass        

        ## Get Q3 anomaly of hindcast series best n RMSE sorted
        AUX_9 = AUX_3['Q3_ANOM_HIND'].values.tolist()       
        if AUX_8:
            Q3_ANOM_HIND_best_n.append(AUX_9[0])    
        else:
            pass

# %%
TTT['INDEX_sort_best_n'] = INDEX_best_n
TTT['RMSE_sort_best_n'] = RMSE_best_n
TTT['Weights_sort_best_n'] = w_best_n
TTT['OBS_ANOM_sort_best_n'] = OBS_ANOM_best_n
TTT['MEAN_ANOM_HIND_best_n'] = MEAN_ANOM_HIND_best_n
TTT['STD_ANOM_HIND_best_n'] = STD_ANOM_HIND_best_n
TTT['Q1_ANOM_HIND_best_n'] = Q1_ANOM_HIND_best_n
TTT['Q3_ANOM_HIND_best_n'] = Q3_ANOM_HIND_best_n

# %%
TTT.head(15)
# Out:
#          DATE  MONTH_PRED  YEAR_PRED MONTH_PRED_cal  \
# 0  1980-07-01           7       1980            Jul
# 1  1980-08-01           8       1980            Aug
# 2  1980-09-01           9       1980            Sep
# 3  1980-10-01          10       1980            Oct
# 4  1980-11-01          11       1980            Nov
# 5  1980-12-01          12       1980            Dec
# 6  1981-01-01           1       1981            Jan
# 7  1981-02-01           2       1981            Feb
# 8  1981-03-01           3       1981            Mar
# 9  1981-04-01           4       1981            Apr
# 10 1981-05-01           5       1981            May
# 11 1981-06-01           6       1981            Jun
# 12 1981-07-01           7       1981            Jul
# 13 1981-08-01           8       1981            Aug
# 14 1981-09-01           9       1981            Sep
#
#             INDEX_sort_best_n                          RMSE_sort_best_n  \
# 0             [9, 4, 1, 0, 5]  [0.8149, 0.8291, 1.0145, 1.2759, 1.4397]
# 1        [14, 11, 10, 19, 15]  [0.7295, 0.9818, 0.9915, 1.1493, 1.3036]
# 2        [24, 21, 20, 27, 25]  [0.4064, 0.9826, 0.9965, 1.3349, 1.3788]
# 3        [34, 30, 35, 37, 32]   [0.5056, 0.8776, 1.2272, 1.3386, 1.435]
# 4        [44, 40, 45, 42, 47]    [0.417, 0.7762, 0.905, 1.2747, 1.4849]
# 5        [54, 50, 55, 52, 57]   [0.4433, 0.8562, 1.026, 1.0935, 1.2393]
# 6        [60, 64, 62, 67, 68]  [0.8256, 1.0054, 1.2525, 1.4123, 1.5856]
# 7        [70, 74, 72, 78, 77]  [0.9869, 1.0182, 1.2754, 1.3655, 1.3798]
# 8        [79, 83, 87, 82, 81]  [0.9849, 1.0726, 1.3487, 1.3797, 1.4554]
# 9        [88, 92, 96, 90, 91]   [0.902, 1.0416, 1.3212, 1.3956, 1.4474]
# 10    [97, 101, 105, 99, 104]  [0.7581, 1.0577, 1.2997, 1.3554, 1.4291]
# 11  [106, 110, 108, 114, 109]    [0.728, 1.1721, 1.334, 1.3842, 1.4634]
# 12  [120, 116, 117, 119, 124]  [0.7912, 0.8445, 1.0634, 1.1145, 1.2418]
# 13  [126, 130, 125, 129, 127]  [0.6439, 0.7798, 0.9915, 1.0389, 1.0729]
# 14  [136, 139, 140, 135, 137]  [0.6392, 0.7871, 0.8064, 0.9965, 1.0701]
#
#                                   Weights_sort_best_n  \
# 0   [0.250574, 0.246283, 0.201274, 0.160038, 0.14183]
# 1   [0.272248, 0.202287, 0.200308, 0.172805, 0.152...
# 2   [0.413118, 0.170864, 0.168481, 0.125771, 0.121...
# 3   [0.367897, 0.211951, 0.151572, 0.138958, 0.129...
# 4   [0.383734, 0.206155, 0.176815, 0.125533, 0.107...
# 5   [0.368607, 0.190847, 0.159263, 0.149432, 0.131...
# 6   [0.278894, 0.229018, 0.183836, 0.163035, 0.145...
# 7   [0.239175, 0.231822, 0.185073, 0.172861, 0.171...
# 8   [0.247582, 0.227339, 0.180799, 0.176737, 0.167...
# 9   [0.261904, 0.226803, 0.178805, 0.169273, 0.163...
# 10    [0.295001, 0.21144, 0.17207, 0.164999, 0.15649]
# 11  [0.313456, 0.19469, 0.171061, 0.164858, 0.155935]
# 12  [0.248264, 0.232595, 0.184716, 0.176246, 0.158...
# 13  [0.27063, 0.223466, 0.175752, 0.167734, 0.162418]
# 14  [0.260178, 0.211289, 0.206232, 0.16689, 0.155411]
#
#                                 OBS_ANOM_sort_best_n  MEAN_ANOM_HIND_best_n  \
# 0     [-1.53832, 0.63341, 0.62003, 0.35065, 0.12559]              -0.075830
# 1      [0.22085, 0.23456, 0.41381, -2.18928, 1.3869]              -0.013692
# 2     [0.47592, 0.47972, 0.61431, -1.03157, 1.00309]               0.039331
# 3    [0.67112, -0.67744, 0.77474, -1.14216, 1.35134]              -0.067088
# 4      [0.3367, -1.30647, 1.21781, 0.84712, -0.7264]               0.041469
# 5    [-0.91514, 0.57294, 0.70194, -0.27539, -1.2512]              -0.162202
# 6   [-0.90715, 0.06048, 1.59568, -0.60938, -0.54092]              -0.098902
# 7    [0.16444, -0.40739, 2.25918, 0.59955, -1.34952]               0.046575
# 8    [-0.47138, -1.00258, 0.28523, 0.66713, 1.12386]               0.130716
# 9   [-0.47539, -0.74372, 1.92367, -0.27208, 0.58775]               0.145409
# 10   [0.65669, 0.07577, -0.17033, 0.46017, -1.96632]              -0.137241
# 11     [0.99407, 0.35902, 0.97881, 0.04858, 0.53094]               0.031153
# 12    [0.12559, 0.62003, -0.2901, 0.63341, -1.53832]              -0.038961
# 13      [0.23456, 1.3869, 0.10954, 0.22085, 0.75167]              -0.051726
# 14     [0.47972, 0.47592, 1.00309, -0.35398, 1.5238]              -0.068257
#
#     STD_ANOM_HIND_best_n  Q1_ANOM_HIND_best_n  Q3_ANOM_HIND_best_n
# 0               1.029714            -0.537328             0.555378
# 1               1.068143            -0.444498             0.427325
# 2               1.052424            -0.786416             0.582011
# 3               1.047169            -0.696027             0.675267
# 4               1.060740            -0.749602             0.810985
# 5               0.933941            -0.925055             0.578105
# 6               1.090611            -0.599910             0.027140
# 7               1.065671            -0.300568             0.223171
# 8               1.067735            -0.875094             0.957916
# 9               1.040719            -0.499900             0.686122
# 10              0.972887            -0.736935             0.503327
# 11              1.055501             0.072001             0.608469
# 12              1.052579            -0.537328             0.630197
# 13              1.056095            -0.444498             0.255242
# 14              1.035657            -0.868952             0.478808

# %%
TTT.tail(15)
# Out:
#           DATE  MONTH_PRED  YEAR_PRED MONTH_PRED_cal  \
# 112 1989-11-01          11       1989            Nov
# 113 1989-12-01          12       1989            Dec
# 114 1990-01-01           1       1990            Jan
# 115 1990-02-01           2       1990            Feb
# 116 1990-03-01           3       1990            Mar
# 117 1990-04-01           4       1990            Apr
# 118 1990-05-01           5       1990            May
# 119 1990-06-01           6       1990            Jun
# 120 1990-07-01           7       1990            Jul
# 121 1990-08-01           8       1990            Aug
# 122 1990-09-01           9       1990            Sep
# 123 1990-10-01          10       1990            Oct
# 124 1990-11-01          11       1990            Nov
# 125 1990-12-01          12       1990            Dec
# 126 1991-01-01           1       1991            Jan
#
#                   INDEX_sort_best_n                          RMSE_sort_best_n  \
# 112  [1083, 1084, 1076, 1078, 1080]  [0.7004, 1.5231, 2.0202, 2.1194, 2.1366]
# 113  [1093, 1086, 1094, 1085, 1090]   [0.6515, 1.4511, 1.5994, 1.8371, 2.025]
# 114  [1103, 1096, 1095, 1100, 1098]   [0.6984, 1.2875, 1.5856, 1.7368, 2.093]
# 115  [1113, 1106, 1105, 1110, 1108]  [0.5909, 1.0442, 1.3655, 1.5155, 2.2103]
# 116  [1122, 1115, 1114, 1119, 1118]  [0.9909, 0.9999, 1.3487, 1.5467, 1.5959]
# 117  [1124, 1131, 1123, 1128, 1127]  [0.6723, 1.1336, 1.3212, 1.4536, 1.5072]
# 118  [1133, 1132, 1136, 1137, 1140]  [1.1063, 1.2997, 1.3869, 1.5271, 1.6955]
# 119  [1145, 1142, 1146, 1141, 1144]   [1.0544, 1.154, 1.3336, 1.3842, 1.4857]
# 120  [1150, 1155, 1152, 1153, 1151]  [0.8149, 1.0036, 1.1711, 1.2115, 1.2418]
# 121  [1168, 1160, 1163, 1165, 1161]  [1.0759, 1.1493, 1.3007, 1.3391, 1.4037]
# 122  [1178, 1170, 1175, 1172, 1173]   [1.2662, 1.4766, 1.481, 1.7531, 1.7552]
# 123  [1188, 1180, 1185, 1189, 1181]  [1.1381, 1.4995, 1.6509, 1.8629, 1.9096]
# 124  [1198, 1190, 1199, 1195, 1191]  [1.1256, 1.4944, 1.5231, 1.5827, 1.7076]
# 125  [1208, 1200, 1205, 1209, 1201]   [1.2164, 1.462, 1.5631, 1.5994, 1.7613]
# 126  [1210, 1219, 1218, 1211, 1215]   [1.4424, 1.4696, 1.4945, 1.779, 1.7885]
#
#                                    Weights_sort_best_n  \
# 112  [0.405707, 0.186565, 0.140658, 0.134074, 0.132...
# 113  [0.39484, 0.177271, 0.160834, 0.140024, 0.127031]
# 114  [0.367821, 0.199523, 0.162012, 0.147908, 0.122...
# 115  [0.376525, 0.213071, 0.162936, 0.146809, 0.10066]
# 116  [0.250799, 0.248541, 0.184264, 0.160675, 0.155...
# 117    [0.332172, 0.197, 0.169028, 0.153632, 0.148168]
# 118  [0.248397, 0.211435, 0.198141, 0.17995, 0.162077]
# 119  [0.239477, 0.218808, 0.18934, 0.182419, 0.169956]
# 120  [0.260642, 0.211635, 0.181366, 0.175317, 0.17104]
# 121  [0.230775, 0.216036, 0.19089, 0.185416, 0.176883]
# 122  [0.240608, 0.206324, 0.205711, 0.173782, 0.173...
# 123  [0.273576, 0.207641, 0.188599, 0.167136, 0.163...
# 124  [0.258894, 0.195002, 0.191327, 0.184122, 0.170...
# 125   [0.246222, 0.20486, 0.19161, 0.187261, 0.170048]
# 126  [0.21911, 0.215055, 0.211472, 0.177653, 0.176709]
#
#                                   OBS_ANOM_sort_best_n  MEAN_ANOM_HIND_best_n  \
# 112       [-0.7264, 0.6556, -1.30647, 0.84712, 0.3367]               0.187763
# 113     [-1.2512, 0.57294, 1.26814, 1.29762, -0.91514]               0.029490
# 114    [-0.60938, -0.90715, 0.45825, 0.06048, 1.59568]               0.012116
# 115    [-1.34952, 0.16444, 0.42578, -0.40739, 2.25918]               0.027267
# 116  [-1.10046, -0.47138, -0.45832, -1.00258, 0.66713]               0.048099
# 117  [-0.47539, -1.22165, -0.27447, -0.74372, 0.58775]              -0.098829
# 118     [0.65669, 1.48233, 0.51696, 0.07577, -1.96632]               0.046388
# 119     [0.53094, 0.99407, 0.35902, -0.28038, 0.97881]              -0.005398
# 120      [0.68247, 0.63341, 0.62003, -0.2901, 0.35065]               0.170925
# 121     [-0.48525, 0.10954, 0.75167, 0.22085, 0.41381]               0.273659
# 122     [-1.03157, -0.35398, 0.47592, 0.47972, 1.5238]               0.150123
# 123    [-1.14216, 0.5367, 0.67112, -1.73732, -0.67744]               0.001001
# 124     [-0.7264, -0.33175, -1.5021, 0.3367, -1.30647]              -0.081950
# 125    [-1.2512, 1.29762, -0.91514, -0.23592, 0.57294]              -0.158518
# 126   [0.45825, -0.54092, -0.60938, -0.90715, 0.06048]               0.012116
#
#      STD_ANOM_HIND_best_n  Q1_ANOM_HIND_best_n  Q3_ANOM_HIND_best_n
# 112              0.883310            -0.347535             0.810985
# 113              1.064853            -0.925055             0.724585
# 114              1.090847            -0.599910             0.362784
# 115              1.055929            -0.300568             0.223171
# 116              1.082943            -0.875094             0.957916
# 117              0.801714            -0.499900             0.381389
# 118              1.111898            -0.677871             0.623156
# 119              1.060506            -0.178009             0.608469
# 120              0.892372            -0.190334             0.630197
# 121              0.610381             0.087442             0.427325
# 122              0.933520            -0.271443             0.582011
# 123              1.069040            -0.696027             0.675267
# 124              1.036233            -0.749602             0.810985
# 125              0.940425            -0.925055             0.578105
# 126              1.090847            -0.599910             0.362784

# %%
Pred_Anom = []
for i in TTT.index:
    Pred_Anom.append((TTT['Weights_sort_best_n'][i] * TTT['OBS_ANOM_sort_best_n'][i]).sum())
    
TTT['Frcst_Anom'] = Pred_Anom

# %%
TTT
# Out:
#           DATE  MONTH_PRED  YEAR_PRED MONTH_PRED_cal  \
# 0   1980-07-01           7       1980            Jul
# 1   1980-08-01           8       1980            Aug
# 2   1980-09-01           9       1980            Sep
# 3   1980-10-01          10       1980            Oct
# 4   1980-11-01          11       1980            Nov
# ..         ...         ...        ...            ...
# 122 1990-09-01           9       1990            Sep
# 123 1990-10-01          10       1990            Oct
# 124 1990-11-01          11       1990            Nov
# 125 1990-12-01          12       1990            Dec
# 126 1991-01-01           1       1991            Jan
#
#                   INDEX_sort_best_n                          RMSE_sort_best_n  \
# 0                   [9, 4, 1, 0, 5]  [0.8149, 0.8291, 1.0145, 1.2759, 1.4397]
# 1              [14, 11, 10, 19, 15]  [0.7295, 0.9818, 0.9915, 1.1493, 1.3036]
# 2              [24, 21, 20, 27, 25]  [0.4064, 0.9826, 0.9965, 1.3349, 1.3788]
# 3              [34, 30, 35, 37, 32]   [0.5056, 0.8776, 1.2272, 1.3386, 1.435]
# 4              [44, 40, 45, 42, 47]    [0.417, 0.7762, 0.905, 1.2747, 1.4849]
# ..                              ...                                       ...
# 122  [1178, 1170, 1175, 1172, 1173]   [1.2662, 1.4766, 1.481, 1.7531, 1.7552]
# 123  [1188, 1180, 1185, 1189, 1181]  [1.1381, 1.4995, 1.6509, 1.8629, 1.9096]
# 124  [1198, 1190, 1199, 1195, 1191]  [1.1256, 1.4944, 1.5231, 1.5827, 1.7076]
# 125  [1208, 1200, 1205, 1209, 1201]   [1.2164, 1.462, 1.5631, 1.5994, 1.7613]
# 126  [1210, 1219, 1218, 1211, 1215]   [1.4424, 1.4696, 1.4945, 1.779, 1.7885]
#
#                                    Weights_sort_best_n  \
# 0    [0.250574, 0.246283, 0.201274, 0.160038, 0.14183]
# 1    [0.272248, 0.202287, 0.200308, 0.172805, 0.152...
# 2    [0.413118, 0.170864, 0.168481, 0.125771, 0.121...
# 3    [0.367897, 0.211951, 0.151572, 0.138958, 0.129...
# 4    [0.383734, 0.206155, 0.176815, 0.125533, 0.107...
# ..                                                 ...
# 122  [0.240608, 0.206324, 0.205711, 0.173782, 0.173...
# 123  [0.273576, 0.207641, 0.188599, 0.167136, 0.163...
# 124  [0.258894, 0.195002, 0.191327, 0.184122, 0.170...
# 125   [0.246222, 0.20486, 0.19161, 0.187261, 0.170048]
# 126  [0.21911, 0.215055, 0.211472, 0.177653, 0.176709]
#
#                                  OBS_ANOM_sort_best_n  MEAN_ANOM_HIND_best_n  \
# 0      [-1.53832, 0.63341, 0.62003, 0.35065, 0.12559]              -0.075830
# 1       [0.22085, 0.23456, 0.41381, -2.18928, 1.3869]              -0.013692
# 2      [0.47592, 0.47972, 0.61431, -1.03157, 1.00309]               0.039331
# 3     [0.67112, -0.67744, 0.77474, -1.14216, 1.35134]              -0.067088
# 4       [0.3367, -1.30647, 1.21781, 0.84712, -0.7264]               0.041469
# ..                                                ...                    ...
# 122    [-1.03157, -0.35398, 0.47592, 0.47972, 1.5238]               0.150123
# 123   [-1.14216, 0.5367, 0.67112, -1.73732, -0.67744]               0.001001
# 124    [-0.7264, -0.33175, -1.5021, 0.3367, -1.30647]              -0.081950
# 125   [-1.2512, 1.29762, -0.91514, -0.23592, 0.57294]              -0.158518
# 126  [0.45825, -0.54092, -0.60938, -0.90715, 0.06048]               0.012116
#
#      STD_ANOM_HIND_best_n  Q1_ANOM_HIND_best_n  Q3_ANOM_HIND_best_n  \
# 0                1.029714            -0.537328             0.555378
# 1                1.068143            -0.444498             0.427325
# 2                1.052424            -0.786416             0.582011
# 3                1.047169            -0.696027             0.675267
# 4                1.060740            -0.749602             0.810985
# ..                    ...                  ...                  ...
# 122              0.933520            -0.271443             0.582011
# 123              1.069040            -0.696027             0.675267
# 124              1.036233            -0.749602             0.810985
# 125              0.940425            -0.925055             0.578105
# 126              1.090847            -0.599910             0.362784
#
#      Frcst_Anom
# 0     -0.030739
# 1      0.023441
# 2      0.374478
# 3      0.237200
# 4      0.103257
# ..          ...
# 122    0.124524
# 123   -0.475278
# 124   -0.701107
# 125   -0.164344
# 126   -0.295258
#
# [127 rows x 13 columns]

# %%
TTT['Frcst_Anom_Rest'] = ( TTT['Frcst_Anom'] - TTT['MEAN_ANOM_HIND_best_n'] ) / TTT['STD_ANOM_HIND_best_n']

# %%
HIND_FORECAST_ANALOGUE = pd.DataFrame()
HIND_FORECAST_ANALOGUE['DATE'] = TTT['DATE']
HIND_FORECAST_ANALOGUE['MONTH_PRED'] = TTT['MONTH_PRED']
HIND_FORECAST_ANALOGUE['YEAR_PRED'] = TTT['YEAR_PRED']
HIND_FORECAST_ANALOGUE['FORECAST'] = TTT['Frcst_Anom_Rest']

# %%
ANOMALY_ANALOGUE_TS
# Out:
#      Month  Year  Anomaly_Qlog       DATE
# 0        1  1980     -1.536267 1980-01-01
# 1        2  1980      0.241717 1980-02-01
# 2        3  1980      1.049742 1980-03-01
# 3        4  1980      1.300559 1980-04-01
# 4        5  1980      1.075049 1980-05-01
# ..     ...   ...           ...        ...
# 127      8  1990     -2.189276 1990-08-01
# 128      9  1990     -1.351109 1990-09-01
# 129     10  1990     -0.008010 1990-10-01
# 130     11  1990      0.655603 1990-11-01
# 131     12  1990      1.268143 1990-12-01
#
# [132 rows x 4 columns]

# %%
HIND_FORECAST_ANALOGUE
# Out:
#           DATE  MONTH_PRED  YEAR_PRED  FORECAST
# 0   1980-07-01           7       1980  0.043789
# 1   1980-08-01           8       1980  0.034764
# 2   1980-09-01           9       1980  0.318453
# 3   1980-10-01          10       1980  0.290581
# 4   1980-11-01          11       1980  0.058251
# ..         ...         ...        ...       ...
# 122 1990-09-01           9       1990 -0.027423
# 123 1990-10-01          10       1990 -0.445520
# 124 1990-11-01          11       1990 -0.597506
# 125 1990-12-01          12       1990 -0.006195
# 126 1991-01-01           1       1991 -0.281776
#
# [127 rows x 4 columns]

# %%
OBSERVED_AND_HIND_FORECAST_ANALOGUE = pd.merge(ANOMALY_ANALOGUE_TS, HIND_FORECAST_ANALOGUE[['DATE','FORECAST']], how='left', on='DATE')

# %%
OBSERVED_AND_HIND_FORECAST_ANALOGUE.head(30)
# Out:
#     Month  Year  Anomaly_Qlog       DATE  FORECAST
# 0       1  1980     -1.536267 1980-01-01       NaN
# 1       2  1980      0.241717 1980-02-01       NaN
# 2       3  1980      1.049742 1980-03-01       NaN
# 3       4  1980      1.300559 1980-04-01       NaN
# 4       5  1980      1.075049 1980-05-01       NaN
# 5       6  1980      0.632953 1980-06-01       NaN
# 6       7  1980      0.682468 1980-07-01  0.043789
# 7       8  1980      0.109535 1980-08-01  0.034764
# 8       9  1980     -0.353978 1980-09-01  0.318453
# 9      10  1980      0.536702 1980-10-01  0.290581
# 10     11  1980     -0.331749 1980-11-01  0.058251
# 11     12  1980      1.297617 1980-12-01 -0.171437
# 12      1  1981      0.458249 1981-01-01 -0.022742
# 13      2  1981      0.425784 1981-02-01  0.177545
# 14      3  1981     -0.458319 1981-03-01 -0.110116
# 15      4  1981     -0.274466 1981-04-01 -0.043007
# 16      5  1981      1.482334 1981-05-01  0.088289
# 17      6  1981     -0.280376 1981-06-01  0.576579
# 18      7  1981      0.350652 1981-07-01  0.027624
# 19      8  1981      0.413811 1981-08-01  0.571455
# 20      9  1981      0.614313 1981-09-01  0.654884
# 21     10  1981     -0.677438 1981-10-01  0.451563
# 22     11  1981     -1.306468 1981-11-01  0.113243
# 23     12  1981      0.572945 1981-12-01 -0.006014
# 24      1  1982     -0.907146 1982-01-01  0.130487
# 25      2  1982      0.164443 1982-02-01  0.099638
# 26      3  1982     -0.471385 1982-03-01 -0.429872
# 27      4  1982     -0.475394 1982-04-01  0.062250
# 28      5  1982      0.656692 1982-05-01  0.121580
# 29      6  1982      0.994073 1982-06-01 -0.058622

# %%
OBSERVED_AND_HIND_FORECAST_ANALOGUE.tail(25)
# Out:
#      Month  Year  Anomaly_Qlog       DATE  FORECAST
# 107     12  1988     -1.251198 1988-12-01  0.194524
# 108      1  1989     -0.609378 1989-01-01 -0.069317
# 109      2  1989     -1.349524 1989-02-01  0.257669
# 110      3  1989     -1.100457 1989-03-01 -0.328333
# 111      4  1989     -1.221652 1989-04-01 -0.062878
# 112      5  1989     -1.966323 1989-05-01  0.260753
# 113      6  1989     -2.108455 1989-06-01  0.196077
# 114      7  1989     -1.530132 1989-07-01 -0.115736
# 115      8  1989     -0.442800 1989-08-01  0.037741
# 116      9  1989     -1.350103 1989-09-01  0.429173
# 117     10  1989     -1.737324 1989-10-01 -0.373405
# 118     11  1989     -1.502100 1989-11-01 -0.436501
# 119     12  1989     -0.235918 1989-12-01 -0.143251
# 120      1  1990     -0.540918 1990-01-01 -0.126710
# 121      2  1990      0.599554 1990-02-01 -0.249431
# 122      3  1990      0.285230 1990-03-01 -0.538260
# 123      4  1990      1.923675 1990-04-01 -0.465645
# 124      5  1990     -0.170332 1990-05-01  0.204622
# 125      6  1990      0.048584 1990-06-01  0.502818
# 126      7  1990     -1.538323 1990-07-01  0.294244
# 127      8  1990     -2.189276 1990-08-01 -0.170954
# 128      9  1990     -1.351109 1990-09-01 -0.027423
# 129     10  1990     -0.008010 1990-10-01 -0.445520
# 130     11  1990      0.655603 1990-11-01 -0.597506
# 131     12  1990      1.268143 1990-12-01 -0.006195

# %% [markdown]
# ### Save  OBSERVED_AND_HIND_FORECAST_ANALOGUE

# %%
filename = 'santalucia_caudales_mar2023' + '_FL_' + str(FORECAST_LENGTH) + '_DANA_' + str(DANA)

# %%
filename
# Out:
# 'santalucia_caudales_mar2023_FL_1_DANA_6'

# %%
OBSERVED_AND_HIND_FORECAST_ANALOGUE.to_csv('../data/' + filename + '.csv', index = False)
