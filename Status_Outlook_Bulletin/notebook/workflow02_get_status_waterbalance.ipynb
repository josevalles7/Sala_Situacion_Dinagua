# %%
import argparse
import os
import sys
import pandas as pd

# %%
print(f"Old Directory: {os.getcwd()}")
os.chdir(r'../')
print(f"New Directory: {os.getcwd()}")
# Out:
# Old Directory: d:\GitHub\Sala_Situacion_Dinagua\Status_Outlook_Bulletin\notebook
# New Directory: d:\GitHub\Sala_Situacion_Dinagua\Status_Outlook_Bulletin

# %%
# Import user-defined librarys 
# Define the path to the python HydroSOS Package
sys.path.append('.')

import HydroSOS_scripts.hydrological_status as SOS
import HydroSOS_scripts.flow_aggregation as aggvar

# %%
# Define arguments
'''
parser = argparse.ArgumentParser(
                    prog='calculate_hydrological_status',
                    description='Calculates monthly hydrological status from observation point',
                    epilog='Jose Valles, DINAGUA, 26082024')

#
parser.add_argument('freq', help='provide the input time series frequency (daily or monthly)')
parser.add_argument('input_directory', help='input directory, should ONLY contain .csv daily flow timeseries')
parser.add_argument('output_csv_directory', help='output csv directory')
parser.add_argument('output_json_directory', help='output json directory')

args = parser.parse_args()
'''

args = argparse.Namespace(
    freq='monthly',
    input_directory=r'./waterbalance/input/',
    output_csv_directory=r'./waterbalance/output_csv/01_month/',
    output_json_directory=r'./waterbalance/output_json/01_month/'
)

# %%
for f in os.listdir(args.input_directory):
    if f.endswith('.csv'):
        print(f)
        if args.freq == 'daily':
            print("daily input data found")
            flowdata, stationid = aggvar.import_data(args.input_directory, filename = f)
            MONTHLY_DISCHARGE = aggvar.calculate_monthly(flowdata)
        else:
            print("monthly input data found")
            MONTHLY_DISCHARGE, stationid = aggvar.import_monthly(args.input_directory, filename = f)      
        
        MONTHLY_STATUS = SOS.monthly_status(MONTHLY_DISCHARGE)
        SOS.export_csv(MONTHLY_STATUS, 
                       output_directory = args.output_csv_directory,
                       filename = stationid)
        print("==================================================================")
# Out:
# 10.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 11.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 12.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 13.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 14.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 15.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 16.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 17.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 18.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 19.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 20.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 21.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 22.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 23.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 24.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 26.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 27.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 28.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 29.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 30.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 31.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 32.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 33.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 40.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 41.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 42.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 43.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 44.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 45.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 50.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 51.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 52.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 53.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 54.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 55.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 56.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 57.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 58.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 60.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 61.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 62.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 63.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 64.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 65.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 66.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 67.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================
# 68.csv
# monthly input data found
# CSV FILE GENERATED
# ==================================================================

# %% [markdown]
# ### For Quaterly (3-Month) period

# %%
for f in os.listdir(args.input_directory):
    if f.endswith('.csv'):
        if args.freq == 'daily':
            print("daily input data found")
            flowdata, stationid = aggvar.import_data(args.input_directory, filename = f)
            MONTHLY_DISCHARGE = aggvar.calculate_monthly(flowdata)
        else:
            print("monthly input data found")
            MONTHLY_DISCHARGE, stationid = aggvar.import_monthly(args.input_directory, filename = f)      
        
        DISCHARGE_THREE_MONTHS = aggvar.calculate_accumulated(MONTHLY_DISCHARGE, 3)
        QUATERLY_STATUS = SOS.quarterly_status(DISCHARGE_THREE_MONTHS)
        SOS.export_csv(QUATERLY_STATUS, 
                       output_directory = args.output_csv_directory,
                       filename = stationid)
        print("==================================================================")
