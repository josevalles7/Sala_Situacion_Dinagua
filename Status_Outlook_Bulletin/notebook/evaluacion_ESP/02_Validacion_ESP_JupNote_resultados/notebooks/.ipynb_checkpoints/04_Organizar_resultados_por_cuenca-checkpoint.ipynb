# %%
import pandas as pd
import os

# %%
ruta = r"../Resultados/Tablas_de_metricas_por_lead"

dfs = []

# %%
for archivo in os.listdir(ruta):
    if archivo.endswith(".csv"):
        path = os.path.join(ruta, archivo)
        
        df = pd.read_csv(path)
        df = df.set_index("lead")

        df = df.drop(columns=["NS","Pbias","CV","Pearson","Brier_Q10","Brier_Q10_Q25","Brier_Q25_Q75","Brier_Q75_Q90","Brier_Q90","N_det","N_prob"])
        
        cuenca = os.path.basename(archivo).split("_")[0]
        
        df = df.rename(columns={"CRPSSad": cuenca})
        
        dfs.append(df)

# Concatenar por columnas (alineando por lead)

df_final = pd.concat(dfs, axis=1)
print (df_final)
df_final = df_final.transpose()

# Guardar
df_final.to_csv(os.path.join(r"../Resultados/Metricas_por_cuenca/datos_CRPSSad_por_cuenca.csv"))
# Out:
#             10        11        12        13        14        15        16  \
# lead
# 1     0.164515  0.178071  0.162417  0.181051  0.256791  0.206409  0.249280
# 2     0.055204  0.062550  0.055523  0.065818  0.115553  0.072763  0.095016
# 3     0.013089  0.017472  0.014457  0.019806  0.050859  0.021763  0.033595
# 4     0.006066  0.006183  0.003591  0.005653  0.022344  0.005341  0.011905
# 5     0.000815  0.000479  0.000605  0.001602  0.011038  0.001244  0.004997
# 6     0.000493  0.000666  0.000454  0.000712  0.007148  0.000737  0.003004
#
#             17        18        19  ...        58        60        61  \
# lead                                ...
# 1     0.185894  0.245113  0.287415  ...  0.228125  0.165555  0.178424
# 2     0.054785  0.087361  0.124049  ...  0.077533  0.044641  0.047839
# 3     0.013685  0.036833  0.057280  ...  0.031594  0.012564  0.015961
# 4     0.005179  0.020066  0.032452  ...  0.016500  0.007090  0.008704
# 5     0.003153  0.012297  0.021902  ...  0.009964  0.003708  0.004543
# 6     0.001714  0.006704  0.011847  ...  0.004770  0.000939  0.001430
#
#             62        63        64        65        66        67        68
# lead
# 1     0.245328  0.272115  0.284820  0.195737  0.303994  0.253203  0.291365
# 2     0.100064  0.128708  0.147429  0.064767  0.166546  0.108343  0.139822
# 3     0.044452  0.064524  0.083459  0.025072  0.101782  0.043725  0.066623
# 4     0.026013  0.040768  0.057956  0.010554  0.073935  0.024792  0.040307
# 5     0.013391  0.022305  0.037580  0.005929  0.052638  0.013956  0.023426
# 6     0.006435  0.012649  0.025727  0.002967  0.038998  0.008048  0.013843
#
# [6 rows x 47 columns]
