# %%
# Import libraries
import argparse
import os
import sys
import pandas as pd

# %%
print(f"Old Directory: {os.getcwd()}")
os.chdir(r'../')
print(f"New Directory: {os.getcwd()}")
# Out:
# Old Directory: d:\GitHub\Sala_Situacion_Dinagua\Status_Outlook_Bulletin\notebook
# New Directory: d:\GitHub\Sala_Situacion_Dinagua\Status_Outlook_Bulletin

# %%
# Import user-defined librarys 
# Define the path to the python HydroSOS Package
sys.path.append('.')

import HydroSOS_scripts.hydrological_status as SOS
import HydroSOS_scripts.flow_aggregation as aggvar

# %%
'''parser = argparse.ArgumentParser(
                    prog='calculate_hydrological_status',
                    description='Calculates monthly hydrological status from observation point',
                    epilog='Jose Valles, DINAGUA, 26082024')

parser.add_argument('freq', help='provide the input time series frequency (daily or monthly)')
parser.add_argument('input_directory', help='input directory, should ONLY contain .csv daily flow timeseries')        
parser.add_argument('output_csv_directory', help='output csv directory') 
parser.add_argument('output_json_directory', help='output json directory')

args = parser.parse_args()

'''
args = argparse.Namespace(
    freq='daily',
    input_directory=r'./stations/data/',
    output_csv_directory=r'./stations/output_csv/01_month/',
    output_json_directory=r'./stations/output_json/01_month/'
)

# %%
for f in os.listdir(args.input_directory):
    if f.endswith('.csv'):
        print(f)
        if args.freq == 'daily':
            print("daily input data found")
            flowdata, stationid = aggvar.import_data(args.input_directory, filename = f)
            MONTHLY_DISCHARGE = aggvar.calculate_monthly(flowdata)
        else:
            print("monthly input data found")
            MONTHLY_DISCHARGE, stationid = aggvar.import_monthly(args.input_directory, filename = f)      
        
        MONTHLY_STATUS = SOS.monthly_status(MONTHLY_DISCHARGE)
        SOS.export_csv(MONTHLY_STATUS, 
                       output_directory = args.output_csv_directory,
                       filename = stationid)
        print("==================================================================")

SOS.csv_to_json(args.output_csv_directory, args.output_json_directory)
# Out:
# 101.csv
# daily input data found
# 101
# There are 46 years of data in this file.
# There are 2465 missing data points, which is 14.51% of the total data
# CSV FILE GENERATED
# ==================================================================
# 1170.csv
# daily input data found
# 1170
# There are 46 years of data in this file.
# There are 1492 missing data points, which is 8.79% of the total data
# CSV FILE GENERATED
# ==================================================================
# 1190.csv
# daily input data found
# 1190
# There are 56 years of data in this file.
# There are 467 missing data points, which is 2.28% of the total data
# CSV FILE GENERATED
# ==================================================================
# 1230.csv
# daily input data found
# 1230
# There are 45 years of data in this file.
# There are 1304 missing data points, which is 7.85% of the total data
# CSV FILE GENERATED
# ==================================================================
# 1330.csv
# daily input data found
# 1330
# There are 46 years of data in this file.
# There are 1465 missing data points, which is 8.63% of the total data
# CSV FILE GENERATED
# ==================================================================
# 140.csv
# daily input data found
# 140
# There are 44 years of data in this file.
# There are 2826 missing data points, which is 17.45% of the total data
# CSV FILE GENERATED
# ==================================================================
# 1400.csv
# daily input data found
# 1400
# There are 45 years of data in this file.
# There are 377 missing data points, which is 2.27% of the total data
# CSV FILE GENERATED
# ==================================================================
# 1410.csv
# daily input data found
# 1410
# There are 38 years of data in this file.
# There are 1868 missing data points, which is 13.4% of the total data
# CSV FILE GENERATED
# ==================================================================
# 150.csv
# daily input data found
# 150
# There are 44 years of data in this file.
# There are 442 missing data points, which is 2.7% of the total data
# CSV FILE GENERATED
# ==================================================================
# 1740.csv
# daily input data found
# 1740
# There are 40 years of data in this file.
# There are 2253 missing data points, which is 15.11% of the total data
# CSV FILE GENERATED
# ==================================================================
# 17430.csv
# daily input data found
# 17430
# There are 48 years of data in this file.
# There are 2100 missing data points, which is 11.88% of the total data
# CSV FILE GENERATED
# ==================================================================
# 21530.csv
# daily input data found
# 21530
# There are 33 years of data in this file.
# There are 995 missing data points, which is 8.15% of the total data
# CSV FILE GENERATED
# ==================================================================
# 22060.csv
# daily input data found
# 22060
# There are 51 years of data in this file.
# There are 87 missing data points, which is 0.46% of the total data
# CSV FILE GENERATED
# ==================================================================
# 26662.csv
# daily input data found
# 26662
# There are 43 years of data in this file.
# There are 260 missing data points, which is 1.64% of the total data
# CSV FILE GENERATED
# ==================================================================
# 26665.csv
# daily input data found
# 26665
# There are 43 years of data in this file.
# There are 156 missing data points, which is 0.98% of the total data
# CSV FILE GENERATED
# ==================================================================
# 26669.csv
# daily input data found
# 26669
# There are 43 years of data in this file.
# There are 341 missing data points, which is 2.15% of the total data
# CSV FILE GENERATED
# ==================================================================
# 26676.csv
# daily input data found
# 26676
# There are 43 years of data in this file.
# There are 545 missing data points, which is 3.44% of the total data
# CSV FILE GENERATED
# ==================================================================
# 440.csv
# daily input data found
# 440
# There are 46 years of data in this file.
# There are 2633 missing data points, which is 15.5% of the total data
# CSV FILE GENERATED
# ==================================================================
# 511.csv
# daily input data found
# 511
# There are 42 years of data in this file.
# There are 96 missing data points, which is 0.62% of the total data
# CSV FILE GENERATED
# ==================================================================
# 520.csv
# daily input data found
# 520
# There are 46 years of data in this file.
# There are 272 missing data points, which is 1.61% of the total data
# CSV FILE GENERATED
# ==================================================================
# 531.csv
# daily input data found
# 531
# There are 42 years of data in this file.
# There are 1095 missing data points, which is 7.01% of the total data
# CSV FILE GENERATED
# ==================================================================
# 551.csv
# daily input data found
# 551
# There are 46 years of data in this file.
# There are 326 missing data points, which is 1.92% of the total data
# CSV FILE GENERATED
# ==================================================================
# 591.csv
# daily input data found
# 591
# There are 40 years of data in this file.
# There are 783 missing data points, which is 5.34% of the total data
# CSV FILE GENERATED
# ==================================================================
# 651.csv
# daily input data found
# 651
# There are 43 years of data in this file.
# There are 1152 missing data points, which is 7.35% of the total data
# CSV FILE GENERATED
# ==================================================================
# 820.csv
# daily input data found
# 820
# There are 36 years of data in this file.
# There are 5854 missing data points, which is 44.2% of the total data
# CSV FILE GENERATED
# ==================================================================
# 970.csv
# daily input data found
# 970
# There are 46 years of data in this file.
# There are 1501 missing data points, which is 8.84% of the total data
# CSV FILE GENERATED
# ==================================================================
# JSON FILE GENERATED
